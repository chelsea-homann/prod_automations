# %%
import requests
import pandas as pd
import io
import numpy as np
from io import StringIO
import os
from datetime import date, timedelta
pd.set_option("display.max_rows", 100000, "display.max_columns", 100000)

# %%
username = os.getenv('WDUSER')
password = os.getenv('WDPASSWORD')

# %% [markdown]
# # RaaS Hire Report

# %%
hireend = '2022-12-31'
hirestart = '2000-01-01'

# %%
hire = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Hires?SupervisoryOrg%21WID=fad8c8a44c4510541494e34161d00311&BPStatus%21WID=b90bc51be01d4ae99b603b02b073714d&BPType%21WID=e6591cf3a39e44f0b01c711957f72e76!26627c6715f84ddba510f25c433aeb2b!bd774409e883445d8a773a92274ece71!08e574a19f6b400fac5dbe71ea854f1d!aaa046227982460f98d5a1ca14f91d2b!1758d7cf019a4c6a827fbba824a2866c!c44ef33941cf425f9d4e27e1403c7670&IncludeSubOrgs=1&EffectiveEnd=2021-12-31-08%3A00&EffectiveStart=2000-01-01-08%3A00&Organization%21WID=fad8c8a44c4510541494e34161d00311&EndDate=2022-12-31-08%3A00&StartDate=2014-01-01-08%3A00&format=csv'
with requests.Session() as s:
    download = s.get(hire, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    hire = pd.read_csv(io.StringIO(decoded_content))
    hire = hire.set_index('Emplid')
# Out:
# C:\Users\DDY17\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (14,63,64,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#hire = hire.rename(columns={'Job_Change___Hire_Date':'Job Change / Hire', 'Job_Profile':'Job Profile', 'Job_Requisition':'Job Requisition',
#       'Position_Number':'Position Number', 'Job_Requisition_Status':'Job Requisition Status', 'Job_Req_Fill_Date':'Job Req Fill Date',
#       'Hiring_Manager':'Hiring Manager', 'Hire_Type':'Hire Type', 'Job_Level':'Job Level', 'Grade':'Grade',
#       'Annual_Salary':'Annual Salary', 'Supervisory_Org':'Supervisory Org',
#       'Business_Area':'Business Area', 'Consolidated_Area':'Consolidated Area',
#       'Age_Group':'Age Group', 'Minority___Non-Minority':'Minority','termination_date':'Termination Date',
#       'Termination_Reason':'Termination Reason'})

# %%
print(hire.shape)
hire.head()
# Out:
# (17342, 75)
#                                               Requisition  Position ReqStatus  \
# Emplid
# 93853                               806585 VBS I (Filled)  297030.0    Filled
# 93795                       806128 Test Engineer (Filled)  209966.0    Filled
# 64879            801278 Client Manager Associate (Filled)  285042.0    Filled
# 87237   800719 AVP Global Health and Insurance Program...  284036.0    Filled
# 95075               806195 Chief Medical Officer (Filled)   51323.0    Filled
#
#            ReqOpen      Filled                   ReplacementFor  \
# Emplid
# 93853   2017-08-02  2017-08-02                              NaN
# 93795   2017-06-07  2017-08-14                 Jeanette Fulcher
# 64879   2015-01-26  2015-04-06                              NaN
# 87237   2014-10-30  2015-05-11                              NaN
# 95075   2017-06-16  2018-02-01  Christopher Schenk (Terminated)
#
#             Recruiter     HiringManager PostingSites  HasInternalPostings  \
# Emplid
# 93853      Gigi Jones  Michelle Boucher          NaN                    0
# 93795      Anne Niles     Sagar Chivate          NaN                    0
# 64879      Tara Price  Regina Del Campo          NaN                    0
# 87237      Robyn Cash        Rob Hecker          NaN                    0
# 95075   Gurveen Chana        Liz Walker          NaN                    0
#
#         HasExternalPostings  HasAgencyPostings   Initiated   Effective  \
# Emplid
# 93853                     0                  0  2017-08-02  2017-08-02
# 93795                     0                  0  2017-07-25  2017-08-14
# 64879                     0                  0  2015-03-02  2015-04-06
# 87237                     0                  0  2015-04-01  2015-05-11
# 95075                     0                  0  2017-10-30  2018-02-01
#
#                       Worker                        Type            HireType  \
# Emplid
# 93853   Shruti (Shruti JAin)  Contract Contingent Worker  Contingent Workers
# 93795           Sree Aaloori                        Hire      External Hires
# 64879           Katrina Abad                  Change Job  Internal Transfers
# 87237           Joanne Abate                        Hire      External Hires
# 95075       Syed Zakir Abbas                        Hire      External Hires
#
#         Active  WorkState      AgeGroup  Age  Diverse  Gender  Minority  \
# Emplid
# 93853        0  Tennessee  24 and under    0        0     NaN         0
# 93795        1  Tennessee       30 - 34   33        1  Female         1
# 64879        1   New York       30 - 34   31        1  Female         1
# 87237        1      Maine       50 - 54   54        1  Female         0
# 95075        0     Surrey       45 - 49   49        1    Male         1
#
#         Veteran  Disability Grade                GradeProfile  \
# Emplid
# 93853         0           0   NaN                         NaN
# 93795         0           0   12T                         A21
# 64879         0           0   50A                         NaN
# 87237         0           0   08A                         USA
# 95075         0           0    16  UK – Actuarial, MD, Lawyer
#
#                                          JobLevel    JobCode  \
# Emplid
# 93853                                         NaN      CW001
# 93795   5.2 Professional - Individual Contributor  IT792-USA
# 64879                                     4 Sales  SA483-USA
# 87237                        1.4 AVP & Equivalent  HR220-USA
# 95075                        1.4 AVP & Equivalent    L103-UK
#
#                                      JobProfile  AnnualSalary  \
# Emplid
# 93853                   Contract Service Worker           0.0
# 93795                         Test Engineer, US       76000.0
# 64879                  Client Manager Associate       67600.0
# 87237   AVP, Global Health & Insurance Programs      175000.0
# 95075                     Chief Medical Officer      150000.0
#
#        SupervisoryOrgID                        SupervisoryOrg  \
# Emplid
# 93853   SupOrg_00295931  Colonial Life A&H/Life/Cancer Claims
# 93795   SupOrg_00151825           Administration Journey Tech
# 64879   SupOrg_00203601    Unum US Sales & Client Mgmt - East
# 87237   SupOrg_00103073                    Global HR Benefits
# 95075   SupOrg_00293589             Unum UK Customer Services
#
#        SupervisoryOrgManager      OrgLevel01ID      OrgLevel01  \
# Emplid
# 93853             Gigi Jones  SupOrg_Executive  Unum Executive
# 93795            Eric Rector  SupOrg_Executive  Unum Executive
# 64879       Regina Del Campo  SupOrg_Executive  Unum Executive
# 87237         Linda Levesque  SupOrg_Executive  Unum Executive
# 95075            Steve Harry  SupOrg_Executive  Unum Executive
#
#        OrgLevel01Manager     OrgLevel02ID  OrgLevel02 OrgLevel02Manager  \
# Emplid
# 93853      Rick McKenney  SupOrg_00202594  Unum Group     Rick McKenney
# 93795      Rick McKenney  SupOrg_00202594  Unum Group     Rick McKenney
# 64879         Tom Watjen  SupOrg_00202594  Unum Group     Rick McKenney
# 87237         Tom Watjen  SupOrg_00202594  Unum Group     Rick McKenney
# 95075      Rick McKenney  SupOrg_00202594  Unum Group     Rick McKenney
#
#            OrgLevel03ID               OrgLevel03   OrgLevel03Manager  \
# Emplid
# 93853   SupOrg_00210462       VB & Colonial Life          Tim Arnold
# 93795   SupOrg_00208701          Global Services  Christopher Jerome
# 64879   SupOrg_00112942           Unum Group COO     Michael Simonds
# 87237   SupOrg_00305604  People & Communications      Diane Garofalo
# 95075   SupOrg_00051934       Unum International     Peter O'Donnell
#
#            OrgLevel04ID                    OrgLevel04 OrgLevel04Manager  \
# Emplid
# 93853   SupOrg_00202790  Colonial Life & US VB Claims     Deb Rasmussen
# 93795   SupOrg_00219175        Information Technology  Katherine Miller
# 64879   SupOrg_00115378           Unum Group Benefits        Chris Pyne
# 87237   SupOrg_00103073            Global HR Benefits    Linda Levesque
# 95075   SupOrg_00293589     Unum UK Customer Services       Steve Harry
#
#            OrgLevel05ID                                         OrgLevel05  \
# Emplid
# 93853   SupOrg_00000505                    Colonial Life Disability Claims
# 93795   SupOrg_00217723  UUS: Customer Acquisition and Case Implementation
# 64879   SupOrg_00104630                    UUS Sales and Client Management
# 87237               NaN                                                NaN
# 95075               NaN                                                NaN
#
#           OrgLevel05Manager     OrgLevel06ID  \
# Emplid
# 93853   Christopher Kinback  SupOrg_00295931
# 93795        Oliver McKenna  SupOrg_00151650
# 64879           John Stibal  SupOrg_00111570
# 87237                   NaN              NaN
# 95075                   NaN              NaN
#
#                                   OrgLevel06 OrgLevel06Manager  \
# Emplid
# 93853   Colonial Life A&H/Life/Cancer Claims        Gigi Jones
# 93795                CLA: Field Value Stream       Nick Forbes
# 64879     Unum US Sales & Client Mgmt - East     John Spellane
# 87237                                    NaN               NaN
# 95075                                    NaN               NaN
#
#            OrgLevel07ID                          OrgLevel07 OrgLevel07Manager  \
# Emplid
# 93853               NaN                                 NaN               NaN
# 93795   SupOrg_00151825         Administration Journey Tech       Eric Rector
# 64879   SupOrg_00203601  Unum US Sales & Client Mgmt - East  Regina Del Campo
# 87237               NaN                                 NaN               NaN
# 95075               NaN                                 NaN               NaN
#
#        OrgLevel08ID OrgLevel08 OrgLevel08Manager OrgLevel09ID OrgLevel09  \
# Emplid
# 93853           NaN        NaN               NaN          NaN        NaN
# 93795           NaN        NaN               NaN          NaN        NaN
# 64879           NaN        NaN               NaN          NaN        NaN
# 87237           NaN        NaN               NaN          NaN        NaN
# 95075           NaN        NaN               NaN          NaN        NaN
#
#        OrgLevel09Manager OrgLevel10ID OrgLevel10 OrgLevel10Manager  \
# Emplid
# 93853                NaN          NaN        NaN               NaN
# 93795                NaN          NaN        NaN               NaN
# 64879                NaN          NaN        NaN               NaN
# 87237                NaN          NaN        NaN               NaN
# 95075                NaN          NaN        NaN               NaN
#
#                   BusinessArea                          ProfileArea  \
# Emplid
# 93853     Colonial Life Direct                        Colonial Life
# 93795   Information Technology                         Global Servs
# 64879            US Operations  Unum US Growth Ops & Group Benefits
# 87237   Corporate Staff Direct                         Corporate HR
# 95075                  Unum UK                       Unum UK Direct
#
#                                  Department  ConsolidatedArea  \
# Emplid
# 93853                            CLA Claims            Claims
# 93795                Information Technology       Acquisition
# 64879   Unum US Sales and Client Management             Field
# 87237             Corporate Human Resources   Global Benefits
# 95075             Unum UK Customer Services  Medical Services
#
#                     Area            SubArea                    CostCenter  \
# Emplid
# 93853         Claims Ops  Claims Operations  EC6217 CLA Claims Leadership
# 93795   Acquisition Svcs     Enrollment CoE        EC0572 Enrollment - US
# 64879               East           New York  EC2706 New York Sales Office
# 87237           Benefits          Benefits1               EC9223 Benefits
# 95075   Medical_Services       Medical Svcs       EC7177 Medical Services
#
#                        Location                   Country  \
# Emplid
# 93853             International  United States of America
# 93795   Chattanooga Home Office  United States of America
# 64879       New York City Sales  United States of America
# 87237      Portland Home Office  United States of America
# 95075                   Dorking            United Kingdom
#
#                            Source
# Emplid
# 93853                         NaN
# 93795   Career Section (Inactive)
# 64879        Internal Job Posting
# 87237     Our Employee (Inactive)
# 95075    Social Network: Linkedin

# %%
hire.to_csv(r'O:\people_analytics\scorecards_kpis\ldp\data_build\hire_report_updated.csv')

# %% [markdown]
# # RaaS Internal Job Change Details

# %%
jch_startdate = '2014-01-01'
jch_enddate = (date.today()).strftime('%Y-%m-%d')

# %%
jobchanges = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Internal_Job_Change_Details?SupervisoryOrgFromOrTo%21WID=fad8c8a44c4510541494e34161d00311&BPStatus%21WID=b90bc51be01d4ae99b603b02b073714d&BPType%21WID=e6591cf3a39e44f0b01c711957f72e76!26627c6715f84ddba510f25c433aeb2b!bd774409e883445d8a773a92274ece71!08e574a19f6b400fac5dbe71ea854f1d!367d55bcf1ff49e4afa95b60c8531771!5598cba0054d439690bca4c2a0079eb9!aaa046227982460f98d5a1ca14f91d2b!1758d7cf019a4c6a827fbba824a2866c!c44ef33941cf425f9d4e27e1403c7670&IncludeSubOrgs=1&ChangeEnd={0}-08%3A00&ChangeStart={1}-08%3A00&Organization%21WID=fad8c8a44c4510541494e34161d00311&format=csv'.format(jch_enddate,jch_startdate)
with requests.Session() as s:
    download = s.get(jobchanges, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    jobchanges = pd.read_csv(io.StringIO(decoded_content))
    jobchanges = jobchanges.set_index('Emplid')
# Out:
# C:\Users\DDY17\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (83,84,85) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(jobchanges.shape)
jobchanges.head()
# Out:
# (60026, 134)
#         LANID                Worker        Hire  Active      AgeGroup  Age  \
# Emplid
# 93853   BT417  Shruti (Shruti JAin)  2017-08-02       0  24 and under    0
# 73032   AT412         David A'Hearn  2012-08-06       1   60 and over   62
# 73032   AT412         David A'Hearn  2012-08-06       1   60 and over   62
# 73032   AT412         David A'Hearn  2012-08-06       1   60 and over   64
# 93795   BR417          Sree Aaloori  2017-08-14       1       30 - 34   33
#
#         Diverse  Gender  Minority  Veteran  Disability  HighPotential  \
# Emplid
# 93853         0     NaN         0        0           0              0
# 73032         1    Male         1        0           0              0
# 73032         1    Male         1        0           0              0
# 73032         1    Male         1        0           0              0
# 93795         1  Female         1        0           0              0
#
#                RatingStatus LastRating PotentialRating      Category  \
# Emplid
# 93853   No Potential Rating        NaN             NaN  Data Changes
# 73032   No Potential Rating        NaN             NaN  Data Changes
# 73032   No Potential Rating        NaN             NaN  Data Changes
# 73032   No Potential Rating        NaN             NaN  Data Changes
# 93795   No Potential Rating        NaN             NaN           NaN
#
#                                                    Reason  \
# Emplid
# 93853   Data Change > Data Changes > Same Job - Change...
# 73032   Data Change > Data Changes > Same Job - Change...
# 73032   Data Change > Data Changes > Same Job - Change...
# 73032   Data Change > Data Changes > Same Job - Change...
# 93795                                                 NaN
#
#                                       Type   Effective  \
# Emplid
# 93853   Transfer Contingent Worker Inbound  2018-10-04
# 73032            Transfer Employee Inbound  2017-04-30
# 73032            Transfer Employee Inbound  2017-10-01
# 73032            Transfer Employee Inbound  2019-08-11
# 93795                                 Hire  2017-08-14
#
#                             Completed                    Requisition  \
# Emplid
# 93853   2018-10-04T09:06:11.265-07:00                            NaN
# 73032   2017-04-30T07:07:52.660-07:00                            NaN
# 73032   2017-09-19T05:49:07.415-07:00                            NaN
# 73032   2019-08-02T06:26:34.570-07:00                            NaN
# 93795   2017-07-25T13:46:27.419-07:00  806128 Test Engineer (Filled)
#
#           ReplacementFor  DaysInJobBeforeChange  DaysInPositionBeforeChange  \
# Emplid
# 93853                NaN                    427                         427
# 73032                NaN                   1727                        1727
# 73032                NaN                   1881                        1881
# 73032                NaN                   2560                        2560
# 93795   Jeanette Fulcher                      0                           0
#
#         IsManagerFrom  IsManagerTo  PositionFromID  PositionToID JobCodeFrom  \
# Emplid
# 93853               0            0        297030.0      305545.0       CW001
# 73032               0            0        206804.0      206804.0   CC826-USA
# 73032               0            0        206804.0      206804.0   CC826-USA
# 73032               0            0        206804.0      206804.0   CC826-USA
# 93795               0            0             NaN      209966.0         NaN
#
#         JobCodeTo                 JobProfileFrom  \
# Emplid
# 93853       CW001        Contract Service Worker
# 73032   CC826-USA  Financial Benefits Specialist
# 73032   CC826-USA  Financial Benefits Specialist
# 73032   CC826-USA  Financial Benefits Specialist
# 93795   IT792-USA                            NaN
#
#                          JobProfileTo  \
# Emplid
# 93853         Contract Service Worker
# 73032   Financial Benefits Specialist
# 73032   Financial Benefits Specialist
# 73032   Financial Benefits Specialist
# 93795               Test Engineer, US
#
#                                      JobLevelFrom  \
# Emplid
# 93853                                         NaN
# 73032   5.2 Professional - Individual Contributor
# 73032   5.2 Professional - Individual Contributor
# 73032   5.2 Professional - Individual Contributor
# 93795                                         NaN
#
#                                        JobLevelTo       ManagementLevelFrom  \
# Emplid
# 93853                                         NaN                       NaN
# 73032   5.2 Professional - Individual Contributor  5 Individual Contributor
# 73032   5.2 Professional - Individual Contributor  5 Individual Contributor
# 73032   5.2 Professional - Individual Contributor  5 Individual Contributor
# 93795   5.2 Professional - Individual Contributor                       NaN
#
#                ManagementLevelTo GradeFrom GradeTo  BasePayFrom  BasePayTo  \
# Emplid
# 93853                        NaN       NaN     NaN          0.0        0.0
# 73032   5 Individual Contributor       12F     12F      50000.0    50000.0
# 73032   5 Individual Contributor       12F     12F      50000.0    50000.0
# 73032   5 Individual Contributor         9       9      51765.0    51765.0
# 93795   5 Individual Contributor       NaN     12T          0.0    76000.0
#
#         StockTargetFrom  StockTargetTo StockPlanFrom StockPlanTo  ExemptFrom  \
# Emplid
# 93853               0.0            0.0           NaN         NaN           0
# 73032               0.0            0.0           NaN         NaN           0
# 73032               0.0            0.0           NaN         NaN           0
# 73032               0.0            0.0           NaN         NaN           0
# 93795               0.0            0.0           NaN         NaN           0
#
#         ExemptTo  SchedHoursFrom  SchedHoursTo FullPartTimeFrom  \
# Emplid
# 93853          0            40.0          40.0        Full time
# 73032          0            40.0          40.0        Full time
# 73032          0            40.0          40.0        Full time
# 73032          0            40.0          40.0        Full time
# 93795          1             0.0          40.0              NaN
#
#        FullPartTimeTo   ManagerFrom        ManagerTo SupervisoryOrgFromID  \
# Emplid
# 93853       Full time    Gigi Jones  Tawana Williams      SupOrg_00295931
# 73032       Full time    Tara Moore      Robin Evans      SupOrg_00202766
# 73032       Full time   Robin Evans     Chris Foster      SupOrg_00296509
# 73032       Full time  Chris Foster    Kathy Maloney      SupOrg_00296761
# 93795       Full time           NaN      Eric Rector                  NaN
#
#                             SupervisoryOrgFrom OrgFromManager  \
# Emplid
# 93853     Colonial Life A&H/Life/Cancer Claims     Gigi Jones
# 73032          Unum US Benefits Financial Srvc     Tara Moore
# 73032          Unum US Benefits Financial Srvc    Robin Evans
# 73032   Unum US Benefits Shared Financial Srvc   Chris Foster
# 93795                                      NaN            NaN
#
#         OrgFromLevel01ID  OrgFromLevel01 OrgFromLevel01Manager  \
# Emplid
# 93853   SupOrg_Executive  Unum Executive         Rick McKenney
# 73032   SupOrg_Executive  Unum Executive         Rick McKenney
# 73032   SupOrg_Executive  Unum Executive         Rick McKenney
# 73032   SupOrg_Executive  Unum Executive         Rick McKenney
# 93795                NaN             NaN                   NaN
#
#        OrgFromLevel02ID OrgFromLevel02 OrgFromLevel02Manager OrgFromLevel03ID  \
# Emplid
# 93853   SupOrg_00202594     Unum Group         Rick McKenney  SupOrg_00210462
# 73032   SupOrg_00202594     Unum Group         Rick McKenney  SupOrg_00112942
# 73032   SupOrg_00202594     Unum Group         Rick McKenney  SupOrg_00112942
# 73032   SupOrg_00202594     Unum Group         Rick McKenney  SupOrg_00112942
# 93795               NaN            NaN                   NaN              NaN
#
#             OrgFromLevel03 OrgFromLevel03Manager OrgFromLevel04ID  \
# Emplid
# 93853   VB & Colonial Life            Tim Arnold  SupOrg_00202790
# 73032       Unum Group COO       Michael Simonds  SupOrg_00151199
# 73032       Unum Group COO       Michael Simonds  SupOrg_00151199
# 73032       Unum Group COO       Michael Simonds  SupOrg_00151199
# 93795                  NaN                   NaN              NaN
#
#                       OrgFromLevel04 OrgFromLevel04Manager OrgFromLevel05ID  \
# Emplid
# 93853   Colonial Life & US VB Claims         Deb Rasmussen  SupOrg_00000505
# 73032    Unum US Benefits Operations           Greg Breter  SupOrg_00291783
# 73032    Unum US Benefits Operations           Greg Breter  SupOrg_00291783
# 73032    Unum US Benefits Operations           Greg Breter  SupOrg_00216660
# 93795                            NaN                   NaN              NaN
#
#                                            OrgFromLevel05  \
# Emplid
# 93853                     Colonial Life Disability Claims
# 73032   Unum US LTD Regional Benefits Ops - Chattanoog...
# 73032   Unum US LTD Regional Benefits Ops - Chattanoog...
# 73032                         Unum US Benefits Operations
# 93795                                                 NaN
#
#        OrgFromLevel05Manager OrgFromLevel06ID  \
# Emplid
# 93853    Christopher Kinback  SupOrg_00295931
# 73032              Bob Berry  SupOrg_00150670
# 73032              Bob Berry  SupOrg_00150670
# 73032            Lori Whynot  SupOrg_00100871
# 93795                    NaN              NaN
#
#                                            OrgFromLevel06  \
# Emplid
# 93853                Colonial Life A&H/Life/Cancer Claims
# 73032                     Unum US Benefits Financial Srvc
# 73032                     Unum US Benefits Financial Srvc
# 73032   Unum US Benefits Financial Srvc, LTD Regional ...
# 93795                                                 NaN
#
#        OrgFromLevel06Manager OrgFromLevel07ID  \
# Emplid
# 93853             Gigi Jones              NaN
# 73032            John Howard  SupOrg_00202766
# 73032            John Howard  SupOrg_00296509
# 73032            Joy Michaud  SupOrg_00150670
# 93795                    NaN              NaN
#
#                          OrgFromLevel07 OrgFromLevel07Manager  \
# Emplid
# 93853                               NaN                   NaN
# 73032   Unum US Benefits Financial Srvc            Tara Moore
# 73032   Unum US Benefits Financial Srvc           Robin Evans
# 73032   Unum US Benefits Financial Srvc           John Howard
# 93795                               NaN                   NaN
#
#        OrgFromLevel08ID                   OrgFromLevel08  \
# Emplid
# 93853               NaN                              NaN
# 73032               NaN                              NaN
# 73032               NaN                              NaN
# 73032   SupOrg_00296509  Unum US Benefits Financial Srvc
# 93795               NaN                              NaN
#
#        OrgFromLevel08Manager OrgFromLevel09ID  \
# Emplid
# 93853                    NaN              NaN
# 73032                    NaN              NaN
# 73032                    NaN              NaN
# 73032            Robin Evans  SupOrg_00296761
# 93795                    NaN              NaN
#
#                                 OrgFromLevel09 OrgFromLevel09Manager  \
# Emplid
# 93853                                      NaN                   NaN
# 73032                                      NaN                   NaN
# 73032                                      NaN                   NaN
# 73032   Unum US Benefits Shared Financial Srvc          Chris Foster
# 93795                                      NaN                   NaN
#
#        OrgFromLevel10ID OrgFromLevel10 OrgFromLevel10Manager  \
# Emplid
# 93853               NaN            NaN                   NaN
# 73032               NaN            NaN                   NaN
# 73032               NaN            NaN                   NaN
# 73032               NaN            NaN                   NaN
# 93795               NaN            NaN                   NaN
#
#        SupervisoryOrgToID                                   SupervisoryOrgTo  \
# Emplid
# 93853     SupOrg_00218724  Superior Organization Colonial Life A&H/Life/C...
# 73032     SupOrg_00296509                    Unum US Benefits Financial Srvc
# 73032     SupOrg_00296761             Unum US Benefits Shared Financial Srvc
# 73032     SupOrg_00209704                    Unum US Benefits Financial Srvc
# 93795     SupOrg_00151825                        Administration Journey Tech
#
#            OrgToManager    OrgToLevel01ID    OrgToLevel01 OrgToLevel01Manager  \
# Emplid
# 93853   Tawana Williams  SupOrg_Executive  Unum Executive       Rick McKenney
# 73032       Robin Evans  SupOrg_Executive  Unum Executive       Rick McKenney
# 73032      Chris Foster  SupOrg_Executive  Unum Executive       Rick McKenney
# 73032     Kathy Maloney  SupOrg_Executive  Unum Executive       Rick McKenney
# 93795       Eric Rector  SupOrg_Executive  Unum Executive       Rick McKenney
#
#          OrgToLevel02ID OrgToLevel02 OrgToLevel02Manager   OrgToLevel03ID  \
# Emplid
# 93853   SupOrg_00202594   Unum Group       Rick McKenney  SupOrg_00210462
# 73032   SupOrg_00202594   Unum Group       Rick McKenney  SupOrg_00112942
# 73032   SupOrg_00202594   Unum Group       Rick McKenney  SupOrg_00112942
# 73032   SupOrg_00202594   Unum Group       Rick McKenney  SupOrg_00112942
# 93795   SupOrg_00202594   Unum Group       Rick McKenney  SupOrg_00208701
#
#               OrgToLevel03 OrgToLevel03Manager   OrgToLevel04ID  \
# Emplid
# 93853   VB & Colonial Life          Tim Arnold  SupOrg_00202790
# 73032       Unum Group COO     Michael Simonds  SupOrg_00151199
# 73032       Unum Group COO     Michael Simonds  SupOrg_00151199
# 73032       Unum Group COO     Michael Simonds  SupOrg_00151199
# 93795      Global Services  Christopher Jerome  SupOrg_00219175
#
#                         OrgToLevel04 OrgToLevel04Manager   OrgToLevel05ID  \
# Emplid
# 93853   Colonial Life & US VB Claims       Deb Rasmussen  SupOrg_00000505
# 73032    Unum US Benefits Operations         Greg Breter  SupOrg_00291783
# 73032    Unum US Benefits Operations         Greg Breter  SupOrg_00291783
# 73032    Unum US Benefits Operations         Greg Breter  SupOrg_00216660
# 93795         Information Technology    Katherine Miller  SupOrg_00217723
#
#                                              OrgToLevel05  \
# Emplid
# 93853                     Colonial Life Disability Claims
# 73032   Unum US LTD Regional Benefits Ops - Chattanoog...
# 73032   Unum US LTD Regional Benefits Ops - Chattanoog...
# 73032                         Unum US Benefits Operations
# 93795   UUS: Customer Acquisition and Case Implementation
#
#         OrgToLevel05Manager   OrgToLevel06ID  \
# Emplid
# 93853   Christopher Kinback  SupOrg_00295931
# 73032             Bob Berry  SupOrg_00150670
# 73032             Bob Berry  SupOrg_00150670
# 73032           Lori Whynot  SupOrg_00100871
# 93795        Oliver McKenna  SupOrg_00151650
#
#                                              OrgToLevel06 OrgToLevel06Manager  \
# Emplid
# 93853                Colonial Life A&H/Life/Cancer Claims          Gigi Jones
# 73032                     Unum US Benefits Financial Srvc         John Howard
# 73032                     Unum US Benefits Financial Srvc         John Howard
# 73032   Unum US Benefits Financial Srvc, LTD Regional ...         Joy Michaud
# 93795                             CLA: Field Value Stream         Nick Forbes
#
#          OrgToLevel07ID                                       OrgToLevel07  \
# Emplid
# 93853   SupOrg_00218724  Superior Organization Colonial Life A&H/Life/C...
# 73032   SupOrg_00202766                    Unum US Benefits Financial Srvc
# 73032   SupOrg_00296509                    Unum US Benefits Financial Srvc
# 73032   SupOrg_00150670                    Unum US Benefits Financial Srvc
# 93795   SupOrg_00151825                        Administration Journey Tech
#
#        OrgToLevel07Manager   OrgToLevel08ID  \
# Emplid
# 93853      Tawana Williams              NaN
# 73032           Tara Moore  SupOrg_00296509
# 73032          Robin Evans  SupOrg_00296761
# 73032          John Howard  SupOrg_00104950
# 93795          Eric Rector              NaN
#
#                                   OrgToLevel08 OrgToLevel08Manager  \
# Emplid
# 93853                                      NaN                 NaN
# 73032          Unum US Benefits Financial Srvc         Robin Evans
# 73032   Unum US Benefits Shared Financial Srvc        Chris Foster
# 73032          Unum US Benefits Financial Srvc    Tamra Bevilacqua
# 93795                                      NaN                 NaN
#
#          OrgToLevel09ID                     OrgToLevel09 OrgToLevel09Manager  \
# Emplid
# 93853               NaN                              NaN                 NaN
# 73032               NaN                              NaN                 NaN
# 73032               NaN                              NaN                 NaN
# 73032   SupOrg_00209704  Unum US Benefits Financial Srvc       Kathy Maloney
# 93795               NaN                              NaN                 NaN
#
#        OrgToLevel10ID OrgToLevel10 OrgToLevel10Manager  \
# Emplid
# 93853             NaN          NaN                 NaN
# 73032             NaN          NaN                 NaN
# 73032             NaN          NaN                 NaN
# 73032             NaN          NaN                 NaN
# 93795             NaN          NaN                 NaN
#
#                    LocationFrom               LocationTo  \
# Emplid
# 93853             International            International
# 73032   Chattanooga Home Office  Chattanooga Home Office
# 73032   Chattanooga Home Office  Chattanooga Home Office
# 73032   Chattanooga Home Office  Chattanooga Home Office
# 93795                       NaN  Chattanooga Home Office
#
#             BusinessAreaFrom          BusinessAreaTo          ProfileAreaFrom  \
# Emplid
# 93853   Colonial Life Direct    Colonial Life Direct            Colonial Life
# 73032          US Operations           US Operations  Unum US Benefits Center
# 73032          US Operations           US Operations  Unum US Benefits Center
# 73032          US Operations           US Operations  Unum US Benefits Center
# 93795                    NaN  Information Technology                      NaN
#
#                   ProfileAreaTo               DepartmentFrom  \
# Emplid
# 93853             Colonial Life                   CLA Claims
# 73032   Unum US Benefits Center  Unum US Benefits Operations
# 73032   Unum US Benefits Center  Unum US Benefits Operations
# 73032   Unum US Benefits Center  Unum US Benefits Operations
# 93795              Global Servs                          NaN
#
#                        DepartmentTo ConsolidatedAreaFrom ConsolidatedAreaTo  \
# Emplid
# 93853                    CLA Claims               Claims             Claims
# 73032   Unum US Benefits Operations       Financial Svcs     Financial Svcs
# 73032   Unum US Benefits Operations       Financial Svcs     Financial Svcs
# 73032   Unum US Benefits Operations       Financial Svcs     Financial Svcs
# 93795        Information Technology                  NaN        Acquisition
#
#                   AreaFrom              AreaTo  \
# Emplid
# 93853           Claims Ops          Claims Ops
# 73032   Financial Services  Financial Services
# 73032   Financial Services  Financial Services
# 73032   Financial Services  Financial Services
# 93795                  NaN    Acquisition Svcs
#
#                                SubAreaFrom  \
# Emplid
# 93853                    Claims Operations
# 73032      Chatt Financial Consulting Team
# 73032   Portland Financial Consulting Team
# 73032           Financial Consulting Teams
# 93795                                  NaN
#
#                                  SubAreaTo  \
# Emplid
# 93853              Claims Operations_Other
# 73032      Chatt Financial Consulting Team
# 73032   Portland Financial Consulting Team
# 73032           Financial Consulting Teams
# 93795                       Enrollment CoE
#
#                                       CostCenterFrom  \
# Emplid
# 93853                   EC6217 CLA Claims Leadership
# 73032   EC8113 Financial Consulting Team Chattanooga
# 73032         EC8758 Financial Consulting Team - LTD
# 73032         EC8758 Financial Consulting Team - LTD
# 93795                                            NaN
#
#                                         CostCenterTo
# Emplid
# 93853                         EC6115 CLA Claims VBSs
# 73032   EC8113 Financial Consulting Team Chattanooga
# 73032         EC8758 Financial Consulting Team - LTD
# 73032         EC8758 Financial Consulting Team - LTD
# 93795                         EC0572 Enrollment - US

# %%
jobchanges = jobchanges.rename(columns={'Job_Change_Date':'Job Change Date',
 'Job_Change_Reason':'Job Change Reason',
 'Job_Change_Type':'Job Change Type',
 'Years_in_Job_Profile_Before_Change':'Years in Job Profile Before Change',
 'Time_in_Job_Profile_Before_Change':'Time in Job Profile Before Change',
 'Time_in_Position_Before_Change':'Time in Position Before Change',
 'Job_Code_-_From':'Job Code - From',
 'Job_Code_-_To':'Job Code - To',
 'Job_Profile_-_From':'Job Profile - From',
 'Job_Profile_-_To':'Job Profile - To',
 'Grade_-_From': 'Grade - From',
 'Grade_-_To':'Grade - To',
 'Job_Level_From':'Job Level From',
 'Job_Level_To':'Job Level To',
 'Is_Manager_From':'Is Manager - From',
 'Is_Manager_To':'Is Manager - To',                                        
 'Base_Pay_-_From':'Base Pay - From',
 'Base_Pay_-_To':'Base Pay - To',
 'Sched_Hours_-_From':'Sched Hours - From',
 'Sched_Hours_-_To':'Sched Hours - To',
 'Manager_-_From':'Manager - From',
 'Manager_-_To':'Manager - To',
 'Supervisory_Org_-_From':'Supervisory Org - From',
 'Supervisory_Org_-_To':'Supervisory Org - To',
 'Location_-_From':'Location - From',
 'Location_-_To':'Location - To',
 'Cost_Center_-_From':'Cost Center - From',
 'Cost_Center_-_To':'Cost Center - To',
 'Business_Area_-_From':'Business Area - From',
 'Business_Area_-_To':'Business Area - To',
 'Profile_Area_-_From':'Profile Area - From',
 'Profile_Area_-_To':'Profile Area - To',
 'Department_-_From':'Department - From',
 'Department_-_To':'Department - To',
 'Consolidated_Area_-_From':'Consolidated Area - From',
 'Consolidated_Area_-_To':'Consolidated Area - To',
 'Area_-_To':'Area - To',
 'Sub_Area_-_To':'Sub Area - To',
 'Potential_Rating':'Potential Rating',
 'Rating_Status':'Rating Status',
 'Last_Rating':'Last Rating'})

# %%
#jobchanges.to_csv(r'O:\people_analytics\scorecards_kpis\ldp\data_build\internal_job_changes_update.csv')
jobchanges.to_csv(r'C:\Users\DDY17\OneDrive - Unum\R Files\job_changes_2017_now.csv')

# %% [markdown]
# # RaaS Terminated Worker Details (2014+)

# %%
termstart = '2000-01-01'
termend = (date.today()).strftime('%Y-%m-%d')

# %%
terminations = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Terminated_Worker_Details__2014__?Term_Start_Date={0}-08%3A00&Term_End_Date={1}-08%3A00&Supervisory_Organization%21WID=fad8c8a44c4510541494e34161d00311&Employee_Type%21WID=c4ed1a5d88a41050a1f47a5de48823db!c4ed1a5d88a41050a1f47c52de8823dc&format=csv'.format(termstart,termend)
with requests.Session() as s:
    download = s.get(terminations, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    terminations = pd.read_csv(io.StringIO(decoded_content))
    terminations = terminations.set_index('Employee_ID')

# %%
print(terminations.shape)
terminations.head()
# Out:
# (10337, 52)
#              LANID              Name            primaryWorkEmail  \
# Employee_ID
# 95075        D1P17  Syed Zakir Abbas  SyedZakir.Abbas@unum.co.uk
# 12440        ASH10  Ann-Marie Abbott           AAbbott3@UNUM.COM
# 96931        BG218    Brandon Abbott    BAbbott@ColonialLife.com
# 99121        D7I18    Michael Abbott           MAbbott2@UNUM.COM
# 71693          NaN      Shenaid Abbs               unum@unum.com
#
#             Most_Recent_Hire_Date Original_Hire_Date Most_Recent_Term_Date  \
# Employee_ID
# 95075                  2018-02-01         2018-02-01            2020-12-30
# 12440                  2011-07-01         1985-06-17            2015-06-30
# 96931                  2018-06-11         2018-06-11            2018-08-31
# 99121                  2018-12-03         2018-12-03            2020-01-20
# 71693                  2011-09-19         2011-09-19            2014-03-28
#
#             Is_Term_90_Day_Hire     Term_Reason Secondary_Term_Reason  \
# Employee_ID
# 95075                         N    No Placement                   NaN
# 12440                         N  LTD - 6 Months                   NaN
# 96931                         Y        Personal                   NaN
# 99121                         N  Other Position                   NaN
# 71693                         N        Personal                   NaN
#
#                           Term_Category  \
# Employee_ID
# 95075        Job Elimination/Redundancy
# 12440                             Other
# 96931                         Voluntary
# 99121                         Voluntary
# 71693                         Voluntary
#
#              Employee_has_had_Performance_Improvement_or_Reprimand_Plan  \
# Employee_ID
# 95075                                                        0
# 12440                                                        0
# 96931                                                        0
# 99121                                                        0
# 71693                                                        0
#
#             Eligible_for_Rehire                   Job_Profile  \
# Employee_ID
# 95075                       NaN         Chief Medical Officer
# 12440                       NaN       Sr. Staffing Consultant
# 96931                       NaN                   Manager III
# 99121                        No    Dir, Policies & Procedures
# 71693                       NaN  Snr Customer Fdbk Specialist
#
#                            Time_in_Job_Profile  \
# Employee_ID
# 95075        2 year(s), 10 month(s), 29 day(s)
# 12440        3 year(s), 11 month(s), 29 day(s)
# 96931         0 year(s), 2 month(s), 20 day(s)
# 99121         1 year(s), 1 month(s), 17 day(s)
# 71693         0 year(s), 6 month(s), 26 day(s)
#
#              Time_in_Job_Profile__Partial_Years_   Job_Code  \
# Employee_ID
# 95075                                       2.91    L103-UK
# 12440                                       4.00  HR508-USA
# 96931                                       0.22  CS512-USA
# 99121                                       1.13  UW459-USA
# 71693                                       0.57   UA001-UK
#
#                                              Job_Level Grade  Annual_Salary  \
# Employee_ID
# 95075                              1.3 VP & Equivalent    16       151500.0
# 12440                                       3 Managers   11E        81143.0
# 96931                                       3 Managers    13        75000.0
# 99121                                      2 Directors    14       110000.0
# 71693        5.2 Professional - Individual Contributor   4UA        23200.0
#
#             Worker_Type  Time_Type Employee_Type  Scheduled_Hours  Exempt_  \
# Employee_ID
# 95075          Employee  Part time       Regular            29.00        0
# 12440          Employee  Full time       Regular            40.00        1
# 96931          Employee  Full time       Regular            40.00        1
# 99121          Employee  Full time       Regular            40.00        1
# 71693          Employee  Full time       Regular            36.25        0
#
#              Job_Exempt_Applies           Job_Family    Job_Family_Group  \
# Employee_ID
# 95075                         0              Doctors                 NaN
# 12440                         1            All Other  Other Job Families
# 96931                         1    Customer Services                 NaN
# 99121                         1  Operational Support                 NaN
# 71693                         0            All Other  Other Job Families
#
#                      Manager                  Leadership_Role  \
# Employee_ID
# 95075             Liz Walker                  1 Senior Leader
# 12440         Marcia Leander  4 Senior Individual Contributor
# 96931        Kevin Pillsbury                     3 Management
# 99121        Jennifer Robare                     3 Management
# 71693          Peter Goddard         5 Individual Contributor
#
#                               location     Campus  \
# Employee_ID
# 95075                          Dorking    Dorking
# 12440             Portland Home Office   Portland
# 96931        Colonial Life Home Office   Columbia
# 99121            Worcester Home Office  Worcester
# 71693                          Dorking        NaN
#
#                                       Supervisory_Organization  \
# Employee_ID
# 95075                   Unum UK Customer Services (Liz Walker)
# 12440        Executive Recruiting and TA Operations (Marcia...
# 96931                  US Service Operations (Kevin Pillsbury)
# 99121        Unum US IDI Policy & Practice, Training & QR (...
# 71693                    UK Legal & Compliance (Peter Goddard)
#
#             Tenure_Category_-_Position  Years_of_Service  \
# Employee_ID
# 95075                    02 - 05 Years              2.91
# 12440                    02 - 05 Years              4.00
# 96931                    00 - 01 Years              0.22
# 99121                    01 - 02 Years              1.13
# 71693                    02 - 05 Years              2.52
#
#              Years_in_Current_Position Time_in_Job_Profile_Start_Date  Gender  \
# Employee_ID
# 95075                             2.91                     2018-02-01    Male
# 12440                             4.00                     2011-07-01  Female
# 96931                             0.22                     2018-06-11    Male
# 99121                             1.13                     2018-12-03    Male
# 71693                             0.57                     2013-09-02  Female
#
#                                 Race_Ethnicity  Hispanic_or_Latino  \
# Employee_ID
# 95075               Pakistani (United Kingdom)                 NaN
# 12440         White (United States of America)                 0.0
# 96931         White (United States of America)                 0.0
# 99121         White (United States of America)                 0.0
# 71693        White (United Kingdom) (inactive)                 NaN
#
#              Disability              Veteran     Age_Group  Age  \
# Employee_ID
# 95075                 0  Veteran Status = No       50 - 54   52
# 12440                 0  Veteran Status = No       55 - 59   58
# 96931                 0  Veteran Status = No       30 - 34   34
# 99121                 0  Veteran Status = No       50 - 54   50
# 71693                 0  Veteran Status = No  24 and under   24
#
#                                      Cost_Center       Email_-_Primary_Home  \
# Employee_ID
# 95075                    EC7177 Medical Services  zakirabbas@doctors.org.uk
# 12440        EC0311 Executive Talent Acquisition      placeholder@email.com
# 96931              EC6172 Account Services Admin       abbottbn@hotmail.com
# 99121                      EC8358 IDI P&P and QA      mabbo1105@comcast.net
# 71693                EC7021 Insurance Compliance      placeholder@email.com
#
#                 Term_Location_Country    Profile_Area_Division  \
# Employee_ID
# 95075                  United Kingdom           Unum UK Direct
# 12440        United States of America             Corporate HR
# 96931        United States of America            Colonial Life
# 99121        United States of America  Unum Specialty Business
# 71693                  United Kingdom           Unum UK Direct
#
#                                   Department          Consolidated_Area  \
# Employee_ID
# 95075              Unum UK Customer Services     Customer Care Services
# 12440              Corporate Human Resources  Global Talent Acquisition
# 96931                CLA Customer Operations       CLA Account Services
# 99121        Unum US_IDI Business Operations    IDI Business Operations
# 71693            Unum UK Risk and Governance       Corporate - Services
#
#                                          Area                    Sub-Area  \
# Employee_ID
# 95075                      Customer Care Srvs              Claims_Subarea
# 12440        Active EE-Global Talent Mgt Corp  Staffing/Recruiting1 Progs
# 96931                           AS Leadership              CLA_Leadership
# 99121                     IDI Shared Services     IDI Employee Experience
# 71693                     Corporate__Services          Compliance_Subarea
#
#             Potential_-_Completed_Rating
# Employee_ID
# 95075                        Well Placed
# 12440                                NaN
# 96931                                NaN
# 99121                        Well Placed
# 71693                                NaN

# %%
terminations = terminations.rename(columns={'Employee_ID':'Employee ID',
  'primaryWorkEmail':'Email - Primary Work',
 'Hire_Date':'Hire Date',
 'Term_Date':'Term Date',
 'Terminated__based_on_report_date_':'Terminated Based on Report Date',
 'CF_Worker_Latest_Term_Date':'CF Worker Lastest Term Date',
 'Is_Term_90_Day_Hire':'Is Term 90 Day Hire',
 'Term_Reason':"Term Reason",
 'termination_primary':'Termination Primary',
 'Secondary_Term_Reason':'Secondary Term Reason',
 'Term_Category':'Term Category',
 'Employee_has_had_Performance_Improvement_or_Reprimand_Plan':'Employee had has Performance Improvement or Reprimand Plan',
 'Eligible_for_Rehire':'Eligible for Rehire',
 'Job_Profile':'Job Profile',
 'Time_in_Job_Profile':'Time in Job Profile',
 'Job_Code':'Job Code',
 'Job_Level':'Job Level',
 'Annual_Salary':'Annual Salary',
 'Worker_Type':'Worker Type',
 'Time_Type':'Time Type',
 'Employee_Type':'Employee Type',
 'Scheduled_Hours':'Scheduled Hours',
 'Exempt_':'Exempt',
 'Job_Exempt_Applies':'Job Exempt Applies',
 'Job_Family':'Job Family',
 'Job_Family_Group':'Job Family Group',
 'Leadership_Role':'Leadership Role',
 'location':'Location',
 'Supervisory_Organization':'Supervisory Organization',
 'Tenure_Category_-_Position':'Tenure Category - Position',
 'Years_of_Service':'Years of Service',
 'Race_Ethnicity':'Race Ethnicity',
 'Hispanic_or_Latino':'Hispanic or Latino',
 'Age_Group':'Age Group',
 'Cost_Center':'Cost Center',
 'Email_-_Work':'Email - Work',
 'Profile_Area_Division':'Profile Area Division',
 'Consolidated_Area':'Consolidated Area',
 'Potential_-_Completed_Rating':'Potential - Completed Rating',
 'Last_Update_-_Potential':'Last Update - Potential',
 'effectiveDate':'Effective Date',
 'staffingPlanTitle':'Staffing Plan Title',
 'fieldOfficeProfileIndicator':'Field Office Profile Indicator'})

# %%
terminations.to_csv(r'O:\people_analytics\scorecards_kpis\ldp\data_build\term_worker_details.csv')

# %% [markdown]
# # RaaS Candidate Data

# %% [markdown]
# ### ADP/AFDP Candidate Data

# %%
adp_afdp_candidates = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Candidate_Data?Internal=0&Job_Profile%21WID=2a18aa346de810528f0098df37904f81!2a18aa346de810528f00a35f6b404f8d!2a18aa346de810528f00a72729704f91!a9ad2a8b8c5301f3e4df754e01507b93&format=csv'
with requests.Session() as s:
    download = s.get(adp_afdp_candidates, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    adp_afdp_candidates = pd.read_csv(io.StringIO(decoded_content))
    adp_afdp_candidates = adp_afdp_candidates.set_index('Candidate')

# %%
print(adp_afdp_candidates.shape)
adp_afdp_candidates.head()
# Out:
# (6178, 46)
#                Candidate_ID           Stage                         Status  \
# Candidate
# Kyle Choate          C10389  Ready for Hire                          Hired
# Aaron Gulibon        C31496        Rejected  No longer under consideration
# Aaron Rosauer        C32130        Rejected  No longer under consideration
# ABBEY ZHENG          C39516        Rejected  No longer under consideration
# Adnan Naufaldi       C22299        Rejected  No longer under consideration
#
#                Last_Recruiting_Stage  \
# Candidate
# Kyle Choate           Ready for Hire
# Aaron Gulibon                 Screen
# Aaron Rosauer                 Screen
# ABBEY ZHENG                   Review
# Adnan Naufaldi        Administrative
#
#                                                Disposition_Reason  \
# Candidate
# Kyle Choate                                                   NaN
# Aaron Gulibon                           Candidate did not respond
# Aaron Rosauer                                  Position is filled
# ABBEY ZHENG     Requires employment sponsorship (now or in the...
# Adnan Naufaldi                          Candidate did not respond
#
#                 Candidate_Disposition_Reason  Internal_ App_Created  \
# Candidate
# Kyle Choate                              NaN          0  2017-10-23
# Aaron Gulibon                            NaN          0  2018-01-31
# Aaron Rosauer                            NaN          0  2018-02-03
# ABBEY ZHENG                              NaN          0  2018-03-07
# Adnan Naufaldi                           NaN          0  2017-12-19
#
#                 Employee_ID termination_date   Hire_Date  \
# Candidate
# Kyle Choate         96716.0              NaN  2018-06-04
# Aaron Gulibon           NaN              NaN         NaN
# Aaron Rosauer           NaN              NaN         NaN
# ABBEY ZHENG             NaN              NaN         NaN
# Adnan Naufaldi          NaN              NaN         NaN
#
#                JKCF_-_Format_App_Created_Date__MM-YYYY_  Do_Not_Hire  \
# Candidate
# Kyle Choate                                     Q4-2017            0
# Aaron Gulibon                                   Q1-2018            0
# Aaron Rosauer                                   Q1-2018            0
# ABBEY ZHENG                                     Q1-2018            0
# Adnan Naufaldi                                  Q4-2017            0
#
#                       Step CF_Calc_Candidate_Stage  \
# Candidate
# Kyle Choate     Completion          Ready for Hire
# Aaron Gulibon          NaN                  Screen
# Aaron Rosauer          NaN                  Screen
# ABBEY ZHENG            NaN                  Review
# Adnan Naufaldi         NaN          Administrative
#
#                                                        App_Source  \
# Candidate
# Kyle Choate                        Job Board -> Indeed (inactive)
# Aaron Gulibon   College/University Website or Event -> Univers...
# Aaron Rosauer          Job Board -> Indeed - Sponsored (inactive)
# ABBEY ZHENG     Professional Organization -> All Professional ...
# Adnan Naufaldi            Company Web Site -> Company Career Site
#
#                   Diversity      Minority  Gender  Veteran  Disability  \
# Candidate
# Kyle Choate     Non-Diverse  Non-Minority    Male        0           0
# Aaron Gulibon   Non-Diverse  Non-Minority    Male        0           0
# Aaron Rosauer   Non-Diverse  Non-Minority    Male        0           0
# ABBEY ZHENG         Diverse      Minority  Female        0           0
# Adnan Naufaldi      Diverse      Minority    Male        0           0
#
#                Recruiter Recruiter_s_Department Department  \
# Candidate
# Kyle Choate          NaN                    NaN    Finance
# Aaron Gulibon        NaN                    NaN    Finance
# Aaron Rosauer        NaN                    NaN    Finance
# ABBEY ZHENG          NaN                    NaN    Finance
# Adnan Naufaldi       NaN                    NaN    Finance
#
#                CF_Job_Requisition_Business_Area_SI  \
# Candidate
# Kyle Choate                 Corporate Staff Direct
# Aaron Gulibon               Corporate Staff Direct
# Aaron Rosauer               Corporate Staff Direct
# ABBEY ZHENG                 Corporate Staff Direct
# Adnan Naufaldi              Corporate Staff Direct
#
#                 INT0027_Job_Requisition_Exempt LDCF_EE_SLC_Member  \
# Candidate
# Kyle Choate                                  1          Liz Ahmed
# Aaron Gulibon                                1          Liz Ahmed
# Aaron Rosauer                                1          Liz Ahmed
# ABBEY ZHENG                                  1          Liz Ahmed
# Adnan Naufaldi                               1          Liz Ahmed
#
#                                                       Requisition  \
# Candidate
# Kyle Choate                   806687 Actuarial Assistant (Filled)
# Aaron Gulibon   806732 Finance Development Program Associate (...
# Aaron Rosauer   806732 Finance Development Program Associate (...
# ABBEY ZHENG     806732 Finance Development Program Associate (...
# Adnan Naufaldi  806732 Finance Development Program Associate (...
#
#                 CF_LRV_Job_Req_ID_from_Job_Req             Req_Location  \
# Candidate
# Kyle Choate                             806687  Chattanooga Home Office
# Aaron Gulibon                           806732  Chattanooga Home Office
# Aaron Rosauer                           806732  Chattanooga Home Office
# ABBEY ZHENG                             806732  Chattanooga Home Office
# Adnan Naufaldi                          806732  Chattanooga Home Office
#
#                    Hiring_Mgr                        Job_Profile  \
# Candidate
# Kyle Choate     Emily Kauchak                Actuarial Assistant
# Aaron Gulibon   Emily Kauchak  Finance Development Program Assoc
# Aaron Rosauer   Emily Kauchak  Finance Development Program Assoc
# ABBEY ZHENG     Emily Kauchak  Finance Development Program Assoc
# Adnan Naufaldi  Emily Kauchak  Finance Development Program Assoc
#
#                 Compensation_Grade                                  Job_Level  \
# Candidate
# Kyle Choate                     10  5.2 Professional - Individual Contributor
# Aaron Gulibon                   12                                 3 Managers
# Aaron Rosauer                   12                                 3 Managers
# ABBEY ZHENG                     12                                 3 Managers
# Adnan Naufaldi                  12                                 3 Managers
#
#                Employee_Type Req_Created CF_Job_App_Req_Cmplt_Date  \
# Candidate
# Kyle Choate         External  2017-08-15                2017-08-16
# Aaron Gulibon       External  2017-08-18                2017-08-21
# Aaron Rosauer       External  2017-08-18                2017-08-21
# ABBEY ZHENG         External  2017-08-18                2017-08-21
# Adnan Naufaldi      External  2017-08-18                2017-08-21
#
#                   CF_Job_App_Offer_Cmplt_Date  \
# Candidate
# Kyle Choate     2018-04-10T14:21:42.160-07:00
# Aaron Gulibon                             NaN
# Aaron Rosauer                             NaN
# ABBEY ZHENG                               NaN
# Adnan Naufaldi                            NaN
#
#                JKCF_-_Job_Offer_Complete_Date__Format_Y-Q_  \
# Candidate
# Kyle Choate                                        2018-Q2
# Aaron Gulibon                                          NaN
# Aaron Rosauer                                          NaN
# ABBEY ZHENG                                            NaN
# Adnan Naufaldi                                         NaN
#
#                 JKCF_-_Return_1_for_In_Thru_Review_Stage  \
# Candidate
# Kyle Choate                                            1
# Aaron Gulibon                                          1
# Aaron Rosauer                                          1
# ABBEY ZHENG                                            1
# Adnan Naufaldi                                         0
#
#                 JKCF_-_Return_1_for_In_Thru_Assessment_Stage  \
# Candidate
# Kyle Choate                                                1
# Aaron Gulibon                                              1
# Aaron Rosauer                                              1
# ABBEY ZHENG                                                0
# Adnan Naufaldi                                             0
#
#                 JKCF_-_Return_1_for_In_Thru_Screen_Stage  \
# Candidate
# Kyle Choate                                            1
# Aaron Gulibon                                          1
# Aaron Rosauer                                          1
# ABBEY ZHENG                                            0
# Adnan Naufaldi                                         0
#
#                 JKCF_-_Return_1_for_In_Thru_Interview_Stage  \
# Candidate
# Kyle Choate                                               1
# Aaron Gulibon                                             0
# Aaron Rosauer                                             0
# ABBEY ZHENG                                               0
# Adnan Naufaldi                                            0
#
#                 JKCF_-_Return_1_for_In_Thru_Offer_Stage  \
# Candidate
# Kyle Choate                                           1
# Aaron Gulibon                                         0
# Aaron Rosauer                                         0
# ABBEY ZHENG                                           0
# Adnan Naufaldi                                        0
#
#                 JKCF_-_Return_1_for_In_Thru_Background_Check_Stage  \
# Candidate
# Kyle Choate                                                     1
# Aaron Gulibon                                                   0
# Aaron Rosauer                                                   0
# ABBEY ZHENG                                                     0
# Adnan Naufaldi                                                  0
#
#                 JKCF_-_Return_1_for_In_Thru_Ready_for_Hire_Stage
# Candidate
# Kyle Choate                                                    1
# Aaron Gulibon                                                  0
# Aaron Rosauer                                                  0
# ABBEY ZHENG                                                    0
# Adnan Naufaldi                                                 0

# %%
adp_afdp_candidates = adp_afdp_candidates.rename(columns={'Candidate_ID':'Candidate ID',
 'Last_Recruiting_Stage':'Last Recruiting Stage',
 'Disposition_Reason':'Disposition Reason',
 'Candidate_Disposition_Reason':'Candidate Disposition Reason',
 'Internal_':'Internal',
 'App_Created':'App Created',
 'Employee_ID':'Employee ID',
 'termination_date':'Termination Date',
 'Hire_Date':'Hire Date',
 'JKCF_-_Format_App_Created_Date__MM-YYYY_':'App Created (Quarter-Year)',
 'Do_Not_Hire':'Do Not Hire',
 'CF_Calc_Candidate_Stage':'CF Calc Candidate Stage',
 'App_Source':'App Source',
 'Recruiter_s_Department':'Recruiters Department',
 'CF_Job_Requisition_Business_Area_SI':'Business Area',
 'LDCF_EE_SLC_Member':'SLC Member',
 'Req_Location':'Req Location',
 'Hiring_Mgr':'Hiring Mgr',
 'Job_Profile':'Job Profile',
 'Compensation_Grade':'Compensation Grade',
 'Job_Level':'Job Level',
 'Req_Created':'Req Created',
 'CF_Job_App_Req_Cmplt_Date':'App Created',
 'CF_Job_App_Offer_Cmplt_Date':'Offer Completed',
 'JKCF_-_Job_Offer_Complete_Date__Format_Y-Q_':'Offer Completed (Y-Q)',
 'JKCF_-_Return_1_for_In_Thru_Review_Stage':'In/Thru Review',
 'JKCF_-_Return_1_for_In_Thru_Assessment_Stage':'In/Thru Assessment',
 'JKCF_-_Return_1_for_In_Thru_Screen_Stage':'In/Thru Screen',
 'JKCF_-_Return_1_for_In_Thru_Interview_Stage':'In/Thru Interview',
 'JKCF_-_Return_1_for_In_Thru_Offer_Stage':'In/Thru Offer',
 'JKCF_-_Return_1_for_In_Thru_Background_Check_Stage':'In/Thru Background Check',
 'JKCF_-_Return_1_for_In_Thru_Ready_for_Hire_Stage':'In/Thru Ready for Hire'})

# %%
adp_afdp_candidates.to_csv(r'O:\people_analytics\scorecards_kpis\ldp\data_build\adp_afdp_candidates_export.csv')

# %% [markdown]
# ### PDP Candidate Data

# %%
pdp_candidates = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Candidate_Data?Internal=0&JKCF_-_LRV_Primary_Recruiter_s_Department%21WID=1dd9ce98a6940104889a0b5381d7f3f1&Job_Profile%21WID=2a18aa346de810528f404b23be287596&format=csv'
with requests.Session() as s:
    download = s.get(pdp_candidates, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    pdp_candidates = pd.read_csv(io.StringIO(decoded_content))
    pdp_candidates = pdp_candidates.set_index('Candidate')

# %%
print(pdp_candidates.shape)
pdp_candidates.head()
# Out:
# (2463, 46)
#                      Candidate_ID     Stage                         Status  \
# Candidate
# Aaliyah Boney              C61918  Rejected  No longer under consideration
# Aaron Bertolucci           C91172  Rejected  No longer under consideration
# Aaron Johnson              C52864  Rejected  No longer under consideration
# Aaron Wright               C57059  Rejected  No longer under consideration
# Abdulkhalim Baymatov       C93124  Rejected  No longer under consideration
#
#                      Last_Recruiting_Stage  \
# Candidate
# Aaliyah Boney                       Review
# Aaron Bertolucci                    Review
# Aaron Johnson                       Review
# Aaron Wright                        Screen
# Abdulkhalim Baymatov                Review
#
#                                                     Disposition_Reason  \
# Candidate
# Aaliyah Boney                             Stronger candidate available
# Aaron Bertolucci      Does not meet the required criteria for the role
# Aaron Johnson         Does not meet the required criteria for the role
# Aaron Wright                              Stronger candidate available
# Abdulkhalim Baymatov  Does not meet the required criteria for the role
#
#                       Candidate_Disposition_Reason  Internal_ App_Created  \
# Candidate
# Aaliyah Boney                                  NaN          0  2018-06-17
# Aaron Bertolucci                               NaN          0  2018-10-07
# Aaron Johnson                                  NaN          0  2018-05-29
# Aaron Wright                                   NaN          0  2018-05-23
# Abdulkhalim Baymatov                           NaN          0  2018-10-14
#
#                       Employee_ID termination_date Hire_Date  \
# Candidate
# Aaliyah Boney                 NaN              NaN       NaN
# Aaron Bertolucci              NaN              NaN       NaN
# Aaron Johnson                 NaN              NaN       NaN
# Aaron Wright                  NaN              NaN       NaN
# Abdulkhalim Baymatov          NaN              NaN       NaN
#
#                      JKCF_-_Format_App_Created_Date__MM-YYYY_  Do_Not_Hire  \
# Candidate
# Aaliyah Boney                                         Q2-2018            0
# Aaron Bertolucci                                      Q4-2018            0
# Aaron Johnson                                         Q2-2018            0
# Aaron Wright                                          Q2-2018            0
# Abdulkhalim Baymatov                                  Q4-2018            0
#
#                      Step CF_Calc_Candidate_Stage  \
# Candidate
# Aaliyah Boney         NaN                  Review
# Aaron Bertolucci      NaN                  Review
# Aaron Johnson         NaN                  Review
# Aaron Wright          NaN                  Screen
# Abdulkhalim Baymatov  NaN                  Review
#
#                                                              App_Source  \
# Candidate
# Aaliyah Boney                   Company Web Site -> Company Career Site
# Aaron Bertolucci            Social Network -> Social Network: Glassdoor
# Aaron Johnson               Social Network -> Social Network: Glassdoor
# Aaron Wright                              Referral -> Employee Referral
# Abdulkhalim Baymatov  College/University Website or Event -> Univers...
#
#                         Diversity      Minority  Gender  Veteran  Disability  \
# Candidate
# Aaliyah Boney             Diverse      Minority  Female        1           0
# Aaron Bertolucci      Non-Diverse  Non-Minority    Male        0           0
# Aaron Johnson             Diverse      Minority    Male        0           0
# Aaron Wright              Diverse      Minority    Male        0           0
# Abdulkhalim Baymatov  Non-Diverse  Non-Minority     NaN        0           0
#
#                          Recruiter     Recruiter_s_Department  \
# Candidate
# Aaliyah Boney         Allie Platts  People and Communications
# Aaron Bertolucci      Allie Platts  People and Communications
# Aaron Johnson         Allie Platts  People and Communications
# Aaron Wright          Allie Platts  People and Communications
# Abdulkhalim Baymatov  Allie Platts  People and Communications
#
#                                      Department  \
# Candidate
# Aaliyah Boney         People and Communications
# Aaron Bertolucci      People and Communications
# Aaron Johnson         People and Communications
# Aaron Wright          People and Communications
# Abdulkhalim Baymatov  People and Communications
#
#                      CF_Job_Requisition_Business_Area_SI  \
# Candidate
# Aaliyah Boney                     Corporate Staff Direct
# Aaron Bertolucci                  Corporate Staff Direct
# Aaron Johnson                     Corporate Staff Direct
# Aaron Wright                      Corporate Staff Direct
# Abdulkhalim Baymatov              Corporate Staff Direct
#
#                       INT0027_Job_Requisition_Exempt LDCF_EE_SLC_Member  \
# Candidate
# Aaliyah Boney                                      1          Liz Ahmed
# Aaron Bertolucci                                   1          Liz Ahmed
# Aaron Johnson                                      1          Liz Ahmed
# Aaron Wright                                       1          Liz Ahmed
# Abdulkhalim Baymatov                               1          Liz Ahmed
#
#                                                             Requisition  \
# Candidate
# Aaliyah Boney         809386 Professional Development Program Associ...
# Aaron Bertolucci      809386 Professional Development Program Associ...
# Aaron Johnson         809386 Professional Development Program Associ...
# Aaron Wright          809386 Professional Development Program Associ...
# Abdulkhalim Baymatov  809386 Professional Development Program Associ...
#
#                       CF_LRV_Job_Req_ID_from_Job_Req          Req_Location  \
# Candidate
# Aaliyah Boney                                 809386  Portland Home Office
# Aaron Bertolucci                              809386  Portland Home Office
# Aaron Johnson                                 809386  Portland Home Office
# Aaron Wright                                  809386  Portland Home Office
# Abdulkhalim Baymatov                          809386  Portland Home Office
#
#                          Hiring_Mgr                     Job_Profile  \
# Candidate
# Aaliyah Boney         Hanako Cashin  Prof Development Program Assoc
# Aaron Bertolucci      Hanako Cashin  Prof Development Program Assoc
# Aaron Johnson         Hanako Cashin  Prof Development Program Assoc
# Aaron Wright          Hanako Cashin  Prof Development Program Assoc
# Abdulkhalim Baymatov  Hanako Cashin  Prof Development Program Assoc
#
#                       Compensation_Grade   Job_Level      Employee_Type  \
# Candidate
# Aaliyah Boney                         12  3 Managers           External
# Aaron Bertolucci                      12  3 Managers           External
# Aaron Johnson                         12  3 Managers           External
# Aaron Wright                          12  3 Managers  Referral External
# Abdulkhalim Baymatov                  12  3 Managers           External
#
#                      Req_Created CF_Job_App_Req_Cmplt_Date  \
# Candidate
# Aaliyah Boney         2018-05-17                2018-05-17
# Aaron Bertolucci      2018-05-17                2018-05-17
# Aaron Johnson         2018-05-17                2018-05-17
# Aaron Wright          2018-05-17                2018-05-17
# Abdulkhalim Baymatov  2018-05-17                2018-05-17
#
#                      CF_Job_App_Offer_Cmplt_Date  \
# Candidate
# Aaliyah Boney                                NaN
# Aaron Bertolucci                             NaN
# Aaron Johnson                                NaN
# Aaron Wright                                 NaN
# Abdulkhalim Baymatov                         NaN
#
#                      JKCF_-_Job_Offer_Complete_Date__Format_Y-Q_  \
# Candidate
# Aaliyah Boney                                                NaN
# Aaron Bertolucci                                             NaN
# Aaron Johnson                                                NaN
# Aaron Wright                                                 NaN
# Abdulkhalim Baymatov                                         NaN
#
#                       JKCF_-_Return_1_for_In_Thru_Review_Stage  \
# Candidate
# Aaliyah Boney                                                1
# Aaron Bertolucci                                             1
# Aaron Johnson                                                1
# Aaron Wright                                                 1
# Abdulkhalim Baymatov                                         1
#
#                       JKCF_-_Return_1_for_In_Thru_Assessment_Stage  \
# Candidate
# Aaliyah Boney                                                    0
# Aaron Bertolucci                                                 0
# Aaron Johnson                                                    0
# Aaron Wright                                                     1
# Abdulkhalim Baymatov                                             0
#
#                       JKCF_-_Return_1_for_In_Thru_Screen_Stage  \
# Candidate
# Aaliyah Boney                                                0
# Aaron Bertolucci                                             0
# Aaron Johnson                                                0
# Aaron Wright                                                 1
# Abdulkhalim Baymatov                                         0
#
#                       JKCF_-_Return_1_for_In_Thru_Interview_Stage  \
# Candidate
# Aaliyah Boney                                                   0
# Aaron Bertolucci                                                0
# Aaron Johnson                                                   0
# Aaron Wright                                                    0
# Abdulkhalim Baymatov                                            0
#
#                       JKCF_-_Return_1_for_In_Thru_Offer_Stage  \
# Candidate
# Aaliyah Boney                                               0
# Aaron Bertolucci                                            0
# Aaron Johnson                                               0
# Aaron Wright                                                0
# Abdulkhalim Baymatov                                        0
#
#                       JKCF_-_Return_1_for_In_Thru_Background_Check_Stage  \
# Candidate
# Aaliyah Boney                                                         0
# Aaron Bertolucci                                                      0
# Aaron Johnson                                                         0
# Aaron Wright                                                          0
# Abdulkhalim Baymatov                                                  0
#
#                       JKCF_-_Return_1_for_In_Thru_Ready_for_Hire_Stage
# Candidate
# Aaliyah Boney                                                        0
# Aaron Bertolucci                                                     0
# Aaron Johnson                                                        0
# Aaron Wright                                                         0
# Abdulkhalim Baymatov                                                 0

# %%
pdp_candidates = pdp_candidates.rename(columns={'Candidate_ID':'Candidate ID',
 'Last_Recruiting_Stage':'Last Recruiting Stage',
 'Disposition_Reason':'Disposition Reason',
 'Candidate_Disposition_Reason':'Candidate Disposition Reason',
 'Internal_':'Internal',
 'App_Created':'App Created',
 'Employee_ID':'Employee ID',
 'termination_date':'Termination Date',
 'Hire_Date':'Hire Date',
 'JKCF_-_Format_App_Created_Date__MM-YYYY_':'App Created (Quarter-Year)',
 'Do_Not_Hire':'Do Not Hire',
 'CF_Calc_Candidate_Stage':'CF Calc Candidate Stage',
 'App_Source':'App Source',
 'Recruiter_s_Department':'Recruiters Department',
 'CF_Job_Requisition_Business_Area_SI':'Business Area',
 'LDCF_EE_SLC_Member':'SLC Member',
 'Req_Location':'Req Location',
 'Hiring_Mgr':'Hiring Mgr',
 'Job_Profile':'Job Profile',
 'Compensation_Grade':'Compensation Grade',
 'Job_Level':'Job Level',
 'Req_Created':'Req Created',
 'CF_Job_App_Req_Cmplt_Date':'App Created',
 'CF_Job_App_Offer_Cmplt_Date':'Offer Completed',
 'JKCF_-_Job_Offer_Complete_Date__Format_Y-Q_':'Offer Completed (Y-Q)',
 'JKCF_-_Return_1_for_In_Thru_Review_Stage':'In/Thru Review',
 'JKCF_-_Return_1_for_In_Thru_Assessment_Stage':'In/Thru Assessment',
 'JKCF_-_Return_1_for_In_Thru_Screen_Stage':'In/Thru Screen',
 'JKCF_-_Return_1_for_In_Thru_Interview_Stage':'In/Thru Interview',
 'JKCF_-_Return_1_for_In_Thru_Offer_Stage':'In/Thru Offer',
 'JKCF_-_Return_1_for_In_Thru_Background_Check_Stage':'In/Thru Background Check',
 'JKCF_-_Return_1_for_In_Thru_Ready_for_Hire_Stage':'In/Thru Ready for Hire'})

# %%
pdp_candidates.to_csv(r'O:\people_analytics\scorecards_kpis\ldp\data_build\pdp_candidates_export.csv')

# %% [markdown]
# ### ALP Candidate Data

# %%
alp_candidates = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Candidate_Data?Internal=0&Job_Profile%21WID=a04c256469720175e4e817c392839858&format=csv'
with requests.Session() as s:
    download = s.get(alp_candidates, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    alp_candidates = pd.read_csv(io.StringIO(decoded_content))
    alp_candidates = alp_candidates.set_index('Candidate')

# %%
print(alp_candidates.shape)
alp_candidates.head()
# Out:
# (349, 46)
#                Candidate_ID      Stage                         Status  \
# Candidate
# Aaron Rowan          C17818  Interview         Evaluation in progress
# Abby Tolar          C171681  Interview         Evaluation in progress
# Alex Torpey          C22900   Rejected  No longer under consideration
# Amanda Jimino       C126259  Interview         Evaluation in progress
# Amanda Raffety        C2053  Interview         Evaluation in progress
#
#                Last_Recruiting_Stage            Disposition_Reason  \
# Candidate
# Aaron Rowan                Interview                           NaN
# Abby Tolar                 Interview                           NaN
# Alex Torpey                   Screen  Stronger candidate available
# Amanda Jimino              Interview                           NaN
# Amanda Raffety             Interview                           NaN
#
#                 Candidate_Disposition_Reason  Internal_ App_Created  \
# Candidate
# Aaron Rowan                              NaN          1  2020-02-14
# Abby Tolar                               NaN          1  2020-02-12
# Alex Torpey                              NaN          1  2020-02-14
# Amanda Jimino                            NaN          1  2020-02-14
# Amanda Raffety                           NaN          1  2020-02-07
#
#                 Employee_ID termination_date   Hire_Date  \
# Candidate
# Aaron Rowan         87825.0              NaN  2015-06-22
# Abby Tolar          89951.0       2016-07-21  2017-06-05
# Alex Torpey         73276.0              NaN  2012-10-01
# Amanda Jimino       64569.0              NaN  2007-10-08
# Amanda Raffety      95153.0              NaN  2017-12-11
#
#                JKCF_-_Format_App_Created_Date__MM-YYYY_  Do_Not_Hire  \
# Candidate
# Aaron Rowan                                     Q1-2020            0
# Abby Tolar                                      Q1-2020            0
# Alex Torpey                                     Q1-2020            0
# Amanda Jimino                                   Q1-2020            0
# Amanda Raffety                                  Q1-2020            0
#
#                             Step CF_Calc_Candidate_Stage  \
# Candidate
# Aaron Rowan     Onsite Interview               Interview
# Abby Tolar      Onsite Interview               Interview
# Alex Torpey                  NaN                  Screen
# Amanda Jimino   Onsite Interview               Interview
# Amanda Raffety  Onsite Interview               Interview
#
#                                        App_Source    Diversity      Minority  \
# Candidate
# Aaron Rowan     Job Board -> Internal Job Posting  Non-Diverse  Non-Minority
# Abby Tolar      Job Board -> Internal Job Posting      Diverse  Non-Minority
# Alex Torpey     Job Board -> Internal Job Posting      Diverse  Non-Minority
# Amanda Jimino   Job Board -> Internal Job Posting      Diverse  Non-Minority
# Amanda Raffety  Job Board -> Internal Job Posting      Diverse  Non-Minority
#
#                 Gender  Veteran  Disability     Recruiter  \
# Candidate
# Aaron Rowan       Male        0           0  Allie Platts
# Abby Tolar      Female        0           0  Allie Platts
# Alex Torpey     Female        0           0  Allie Platts
# Amanda Jimino   Female        0           0  Allie Platts
# Amanda Raffety  Female        0           0  Allie Platts
#
#                    Recruiter_s_Department                 Department  \
# Candidate
# Aaron Rowan     People and Communications  People and Communications
# Abby Tolar      People and Communications  People and Communications
# Alex Torpey     People and Communications  People and Communications
# Amanda Jimino   People and Communications  People and Communications
# Amanda Raffety  People and Communications  People and Communications
#
#                CF_Job_Requisition_Business_Area_SI  \
# Candidate
# Aaron Rowan                 Corporate Staff Direct
# Abby Tolar                  Corporate Staff Direct
# Alex Torpey                 Corporate Staff Direct
# Amanda Jimino               Corporate Staff Direct
# Amanda Raffety              Corporate Staff Direct
#
#                 INT0027_Job_Requisition_Exempt LDCF_EE_SLC_Member  \
# Candidate
# Aaron Rowan                                  1          Liz Ahmed
# Abby Tolar                                   1          Liz Ahmed
# Alex Torpey                                  1          Liz Ahmed
# Amanda Jimino                                1          Liz Ahmed
# Amanda Raffety                               1          Liz Ahmed
#
#                                                       Requisition  \
# Candidate
# Aaron Rowan     815450 Accelerated Leadership Program (ALP) (E...
# Abby Tolar      815450 Accelerated Leadership Program (ALP) (E...
# Alex Torpey     815450 Accelerated Leadership Program (ALP) (E...
# Amanda Jimino   815450 Accelerated Leadership Program (ALP) (E...
# Amanda Raffety  815450 Accelerated Leadership Program (ALP) (E...
#
#                 CF_LRV_Job_Req_ID_from_Job_Req          Req_Location  \
# Candidate
# Aaron Rowan                             815450  Portland Home Office
# Abby Tolar                              815450  Portland Home Office
# Alex Torpey                             815450  Portland Home Office
# Amanda Jimino                           815450  Portland Home Office
# Amanda Raffety                          815450  Portland Home Office
#
#                 Hiring_Mgr                     Job_Profile  \
# Candidate
# Aaron Rowan     Kim Bolton  Accelerated Leadership Program
# Abby Tolar      Kim Bolton  Accelerated Leadership Program
# Alex Torpey     Kim Bolton  Accelerated Leadership Program
# Amanda Jimino   Kim Bolton  Accelerated Leadership Program
# Amanda Raffety  Kim Bolton  Accelerated Leadership Program
#
#                 Compensation_Grade  Job_Level Employee_Type Req_Created  \
# Candidate
# Aaron Rowan                    NaN        NaN      Internal  2020-01-29
# Abby Tolar                     NaN        NaN      Internal  2020-01-29
# Alex Torpey                    NaN        NaN      Internal  2020-01-29
# Amanda Jimino                  NaN        NaN      Internal  2020-01-29
# Amanda Raffety                 NaN        NaN      Internal  2020-01-29
#
#                CF_Job_App_Req_Cmplt_Date  CF_Job_App_Offer_Cmplt_Date  \
# Candidate
# Aaron Rowan                   2020-01-29                          NaN
# Abby Tolar                    2020-01-29                          NaN
# Alex Torpey                   2020-01-29                          NaN
# Amanda Jimino                 2020-01-29                          NaN
# Amanda Raffety                2020-01-29                          NaN
#
#                 JKCF_-_Job_Offer_Complete_Date__Format_Y-Q_  \
# Candidate
# Aaron Rowan                                             NaN
# Abby Tolar                                              NaN
# Alex Torpey                                             NaN
# Amanda Jimino                                           NaN
# Amanda Raffety                                          NaN
#
#                 JKCF_-_Return_1_for_In_Thru_Review_Stage  \
# Candidate
# Aaron Rowan                                            1
# Abby Tolar                                             1
# Alex Torpey                                            1
# Amanda Jimino                                          1
# Amanda Raffety                                         1
#
#                 JKCF_-_Return_1_for_In_Thru_Assessment_Stage  \
# Candidate
# Aaron Rowan                                                1
# Abby Tolar                                                 1
# Alex Torpey                                                1
# Amanda Jimino                                              1
# Amanda Raffety                                             1
#
#                 JKCF_-_Return_1_for_In_Thru_Screen_Stage  \
# Candidate
# Aaron Rowan                                            1
# Abby Tolar                                             1
# Alex Torpey                                            1
# Amanda Jimino                                          1
# Amanda Raffety                                         1
#
#                 JKCF_-_Return_1_for_In_Thru_Interview_Stage  \
# Candidate
# Aaron Rowan                                               1
# Abby Tolar                                                1
# Alex Torpey                                               0
# Amanda Jimino                                             1
# Amanda Raffety                                            1
#
#                 JKCF_-_Return_1_for_In_Thru_Offer_Stage  \
# Candidate
# Aaron Rowan                                           0
# Abby Tolar                                            0
# Alex Torpey                                           0
# Amanda Jimino                                         0
# Amanda Raffety                                        0
#
#                 JKCF_-_Return_1_for_In_Thru_Background_Check_Stage  \
# Candidate
# Aaron Rowan                                                     0
# Abby Tolar                                                      0
# Alex Torpey                                                     0
# Amanda Jimino                                                   0
# Amanda Raffety                                                  0
#
#                 JKCF_-_Return_1_for_In_Thru_Ready_for_Hire_Stage
# Candidate
# Aaron Rowan                                                    0
# Abby Tolar                                                     0
# Alex Torpey                                                    0
# Amanda Jimino                                                  0
# Amanda Raffety                                                 0

# %%
alp_candidates = alp_candidates.rename(columns={'Candidate_ID':'Candidate ID',
 'Last_Recruiting_Stage':'Last Recruiting Stage',
 'Disposition_Reason':'Disposition Reason',
 'Candidate_Disposition_Reason':'Candidate Disposition Reason',
 'Internal_':'Internal',
 'App_Created':'App Created',
 'Employee_ID':'Employee ID',
 'termination_date':'Termination Date',
 'Hire_Date':'Hire Date',
 'JKCF_-_Format_App_Created_Date__MM-YYYY_':'App Created (Quarter-Year)',
 'Do_Not_Hire':'Do Not Hire',
 'CF_Calc_Candidate_Stage':'CF Calc Candidate Stage',
 'App_Source':'App Source',
 'Recruiter_s_Department':'Recruiters Department',
 'CF_Job_Requisition_Business_Area_SI':'Business Area',
 'LDCF_EE_SLC_Member':'SLC Member',
 'Req_Location':'Req Location',
 'Hiring_Mgr':'Hiring Mgr',
 'Job_Profile':'Job Profile',
 'Compensation_Grade':'Compensation Grade',
 'Job_Level':'Job Level',
 'Req_Created':'Req Created',
 'CF_Job_App_Req_Cmplt_Date':'App Created',
 'CF_Job_App_Offer_Cmplt_Date':'Offer Completed',
 'JKCF_-_Job_Offer_Complete_Date__Format_Y-Q_':'Offer Completed (Y-Q)',
 'JKCF_-_Return_1_for_In_Thru_Review_Stage':'In/Thru Review',
 'JKCF_-_Return_1_for_In_Thru_Assessment_Stage':'In/Thru Assessment',
 'JKCF_-_Return_1_for_In_Thru_Screen_Stage':'In/Thru Screen',
 'JKCF_-_Return_1_for_In_Thru_Interview_Stage':'In/Thru Interview',
 'JKCF_-_Return_1_for_In_Thru_Offer_Stage':'In/Thru Offer',
 'JKCF_-_Return_1_for_In_Thru_Background_Check_Stage':'In/Thru Background Check',
 'JKCF_-_Return_1_for_In_Thru_Ready_for_Hire_Stage':'In/Thru Ready for Hire'})

# %%
alp_candidates.to_csv(r'O:\people_analytics\scorecards_kpis\ldp\data_build\alp_candidates_export.csv')

# %% [markdown]
# # Turnover

# %%
recordstart = '2021-01-01'
recordend = '2021-12-31'

# %%
turnover = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Trended_Worker_Turnover_Details?IncludeSubOrgs=1&Active=0&Record_Start={0}-08%3A00&Remove_Exclude_From_HC=0&Record_End={1}-08%3A00&SupervisoryOrg%21WID=fad8c8a44c4510541494e34161d00311&format=csv'.format(recordstart,recordend)
with requests.Session() as s:
    download = s.get(turnover, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    turnover = pd.read_csv(io.StringIO(decoded_content))
    turnover = turnover.set_index('Emplid')
# Out:
# C:\Users\DDY17\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11,12,13,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(turnover.shape)
turnover.head()
# Out:
# (52551, 143)
#        Year-Quarter  Month Record_Date Record_Type   LAN_ID    Preferred_Name  \
# Emplid
# 32773       2021-Q1      1  2021-01-01    Activity  #SDINBM        Ben Miller
# 30477       2021-Q1      1  2021-01-01    Activity  H071JTM       John McHugh
# 586         2021-Q1      1  2021-01-01    Activity    C1RGF      Randall Ford
# 1282        2021-Q1      1  2021-01-01    Activity    C1RCL  Randy Laverriere
# 34087       2021-Q1      1  2021-01-01    Activity    JPN0K          Kien Ngo
#
#                                Worker            Work_Email        Hire  \
# Emplid
# 32773         Ben Miller (Terminated)      BMiller@UNUM.COM  1987-03-16
# 30477        John McHugh (Terminated)      JMcHugh@UNUM.COM  1986-11-12
# 586         Randall Ford (Terminated)        rford@unum.com  1981-06-25
# 1282    Randy Laverriere (Terminated)  rlaverriere@unum.com  1983-03-14
# 34087           Kien Ngo (Terminated)         KNgo@UNUM.COM  1982-02-01
#
#        OriginalHireAtRecordDate          Term_Event  \
# Emplid
# 32773                1987-03-16  Terminate Employee
# 30477                1986-11-12  Terminate Employee
# 586                  1981-06-25  Terminate Employee
# 1282                 1983-03-14  Terminate Employee
# 34087                1982-02-01  Terminate Employee
#
#                      Term_Category   Term_Reason Secondary_Term_Reason  \
# Emplid
# 32773   Job Elimination/Redundancy  No Placement                   NaN
# 30477   Job Elimination/Redundancy  No Placement                   NaN
# 586     Job Elimination/Redundancy  No Placement                   NaN
# 1282                     Voluntary    Retirement                   NaN
# 34087                    Voluntary    Retirement                   NaN
#
#         Is_Term_90-Day  Is_Term_New_Hire Is_Rehire_Eligible     Tenure  \
# Emplid
# 32773                0                 0                Yes  25+ Years
# 30477                0                 0                NaN  25+ Years
# 586                  0                 0                NaN  25+ Years
# 1282                 0                 0                Yes  25+ Years
# 34087                0                 0                NaN  25+ Years
#
#         Years_of_Service    Age_Group  Age  Diverse  Gender Gender_Identity  \
# Emplid
# 32773              33.79  60 and over   68        0    Male             NaN
# 30477              34.14      55 - 59   59        0    Male             NaN
# 586                39.52  60 and over   61        0    Male             NaN
# 1282               37.80  60 and over   60        0    Male             NaN
# 34087              38.92  60 and over   60        1  Female             NaN
#
#        Sexual_Orientation Pronoun                         Ethnicity  \
# Emplid
# 32773                 NaN     NaN  White (United States of America)
# 30477                 NaN     NaN  White (United States of America)
# 586                   NaN     NaN  White (United States of America)
# 1282                  NaN     NaN  White (United States of America)
# 34087                 NaN     NaN  Asian (United States of America)
#
#         Hispanic_Latino  Minority MinorityStatus  Disability DisabilityStatus  \
# Emplid
# 32773                 0         0   Non-Minority           0              NaN
# 30477                 0         0   Non-Minority           0              NaN
# 586                   0         0   Non-Minority           0              NaN
# 1282                  0         0   Non-Minority           0              NaN
# 34087                 0         1       Minority           0              NaN
#
#        Disability_Self_ID  Veteran VeteranStatus MilitaryStatus  \
# Emplid
# 32773                 NaN        0           NaN            NaN
# 30477                 NaN        0           NaN            NaN
# 586                   NaN        0           NaN            NaN
# 1282                  NaN        0           NaN            NaN
# 34087                 NaN        0           NaN            NaN
#
#        Highest_Degree  On_Leave  Active                 Management_Level  \
# Emplid
# 32773         Masters         0       0                  1 Senior Leader
# 30477             NaN         0       0         5 Individual Contributor
# 586         Bachelors         0       0                  1 Senior Leader
# 1282        Bachelors         0       0  4 Senior Individual Contributor
# 34087       Bachelors         0       0         5 Individual Contributor
#
#                   Job_Level    Job_Family_Group          Job_Family  \
# Emplid
# 32773   1.3 VP & Equivalent  Other Job Families         Investments
# 30477         6 Entry-Level                 NaN  Supply/Procurement
# 586     1.3 VP & Equivalent     Marketing Group           Marketing
# 1282             3 Managers                 NaN             Finance
# 34087         6 Entry-Level                 NaN   Customer Services
#
#          Job_Code                            Job_Profile Business_Title  \
# Emplid
# 32773   IN200-USA  VP,  Sr. Managing Director (inactive)            NaN
# 30477   SM703-USA                  Logistics  Specialist            NaN
# 586     PR237-USA            VP, NCG Marketing & Distrib            NaN
# 1282    FI679-USA               Senior Financial Analyst            NaN
# 34087   CS401-USA               IDI Service Specialist I            NaN
#
#         YearsInJobAtRecordDate Years_In_Job  \
# Emplid
# 32773                    20.99  20-24 Years
# 30477                     3.02  02-05 Years
# 586                       6.16  05-10 Years
# 1282                      3.21  02-05 Years
# 34087                     5.82  05-10 Years
#
#                                Time_in_Job  Position_ID Grade  Annual_Salary  \
# Emplid
# 32773   20 year(s), 11 month(s), 30 day(s)          NaN    17       244120.0
# 30477      3 year(s), 0 month(s), 7 day(s)          NaN     5        36508.0
# 586       6 year(s), 1 month(s), 30 day(s)          NaN    16       176000.0
# 1282      3 year(s), 2 month(s), 16 day(s)          NaN    12        47622.0
# 34087     5 year(s), 9 month(s), 23 day(s)          NaN     8        50134.0
#
#         Annual_FTE_Salary  Salary_Range_Minimum  Salary_Range_Midpoint  \
# Emplid
# 32773            244120.0                180300            265911.2064
# 30477             36508.0                 31200             40650.0000
# 586              176000.0                132700            182500.0000
# 1282             190488.0                 60100             81100.0000
# 34087             50134.0                 38300             50703.4080
#
#         Salary_Range_Maximum  Is_Org_Manager  Is_People_Manager  \
# Emplid
# 32773                 351600               1                  0
# 30477                  50100               0                  0
# 586                   232200               1                  0
# 1282                  102200               0                  0
# 34087                  63100               0                  0
#
#         Direct_Reports  FTE  Exempt Full_Part_Time Worker_Type Employee_Type  \
# Emplid
# 32773                0  1.0       1      Full time    Employee       Regular
# 30477                0  1.0       0      Full time    Employee       Regular
# 586                  0  1.0       1      Full time    Employee       Regular
# 1282                 0  0.5       1      Part time    Employee       Regular
# 34087                0  1.0       0      Full time    Employee       Regular
#
#        Contingent_Type    Potential  \
# Emplid
# 32773              NaN  Well Placed
# 30477              NaN          NaN
# 586                NaN  Well Placed
# 1282               NaN          NaN
# 34087              NaN  Well Placed
#
#                                            Company                   Country  \
# Emplid
# 32773   C3004 Provident Investment Management, LLC  United States of America
# 30477                             C3035 Unum Group  United States of America
# 586                               C3035 Unum Group  United States of America
# 1282                              C3035 Unum Group  United States of America
# 34087                             C3035 Unum Group  United States of America
#
#                    Campus                 Location Work_Address_State  \
# Emplid
# 32773         Chattanooga  Chattanooga Home Office                NaN
# 30477           Worcester    Worcester Home Office                NaN
# 586              Portland     Portland Home Office                NaN
# 1282             Portland     Portland Home Office                NaN
# 34087   Home Workers - US         Home Worker - US      Massachusetts
#
#                  Business_Area                         Profile_Area  \
# Emplid
# 32773   Corporate Staff Direct                Corporate Investments
# 30477       Corporate Services                        Corp Services
# 586              US Operations  Unum US Growth Ops & Group Benefits
# 1282    Corporate Staff Direct   Corporate Finance and Closed Block
# 34087            US Operations               Unum US Client Success
#
#                            Department           Consolidated_Area  \
# Emplid
# 32773                     Investments            Asset Management
# 30477     Imaging, Records Mgt & Mail  Imag_Records Mgmt and Mail
# 586     Unum US_National Client Group       National Client Group
# 1282                          Finance  Transformation Mgmt Office
# 34087          Unum US_Client Success         IDI Policy Services
#
#                                Area                      Sub_Area  \
# Emplid
# 32773                    Asset Mgmt              Asset_Management
# 30477   Imaging, Records Mgnt, Mail  Imaging, Records Manage_Mail
# 586          NCG Market Development            Market Development
# 1282           Business Performance               Bus Performance
# 34087               Policy Services           IDI_Policy Services
#
#        Cost_Center_ID Cost_Center      BP_Type  End_Headcount  Hires  \
# Emplid
# 32773          EC0901         NaN  Termination              0      0
# 30477          EC0351         NaN  Termination              0      0
# 586            EC1038         NaN  Termination              0      0
# 1282           EC9594         NaN  Termination              0      0
# 34087          EC0681         NaN  Termination              0      0
#
#         Promotion  Transfer_Out  Transfer_In  Termination  \
# Emplid
# 32773           0             0            0            1
# 30477           0             0            0            1
# 586             0             0            0            1
# 1282            0             0            0            1
# 34087           0             0            0            1
#
#         Voluntary_Termination  Involuntary_Termination SupervisoryOrgID  \
# Emplid
# 32773                       0                        1  SupOrg_00210934
# 30477                       0                        1  SupOrg_00116642
# 586                         0                        1  SupOrg_00219654
# 1282                        1                        0  SupOrg_00117136
# 34087                       1                        0  SupOrg_00217735
#
#                                            SupervisoryOrg        OrgManager  \
# Emplid
# 32773                                         Investments     Martha Leiper
# 30477                     Global Services Print & Distrib   Richard Meadows
# 586                                 National Client Group         John King
# 1282    Enterprise Finance Operational Reporting & Ana...  Pamela Carpenter
# 34087                         Unum US IDI Policy Services  Linda Belezarian
#
#         OrgLevel      OrgLevel01ID      OrgLevel01 OrgLevel01Manager  \
# Emplid
# 32773          3  SupOrg_Executive  Unum Executive     Rick McKenney
# 30477          7  SupOrg_Executive  Unum Executive     Rick McKenney
# 586            5  SupOrg_Executive  Unum Executive     Rick McKenney
# 1282           7  SupOrg_Executive  Unum Executive     Rick McKenney
# 34087          6  SupOrg_Executive  Unum Executive     Rick McKenney
#
#            OrgLevel02ID  OrgLevel02 OrgLevel02Manager        OrgLevel03ID  \
# Emplid
# 32773   SupOrg_00202594  Unum Group     Rick McKenney     SupOrg_00210934
# 30477   SupOrg_00202594  Unum Group     Rick McKenney     SupOrg_00211048
# 586     SupOrg_00202594  Unum Group     Rick McKenney     SupOrg_00112942
# 1282    SupOrg_00202594  Unum Group     Rick McKenney  SupOrg_00214583TOP
# 34087   SupOrg_00202594  Unum Group     Rick McKenney     SupOrg_00112942
#
#                 OrgLevel03 OrgLevel03Manager     OrgLevel04ID  \
# Emplid
# 32773          Investments     Martha Leiper              NaN
# 30477     Unum Law & Audit     Lisa Iglesias  SupOrg_00217071
# 586         Unum Group COO   Michael Simonds  SupOrg_00115378
# 1282    Enterprise Finance      Steven Zabel  SupOrg_00214583
# 34087       Unum Group COO   Michael Simonds  SupOrg_00212508
#
#                     OrgLevel04 OrgLevel04Manager     OrgLevel05ID  \
# Emplid
# 32773                      NaN               NaN              NaN
# 30477       Corporate Services      Wendy Gibson  SupOrg_00202805
# 586        Unum Group Benefits        Chris Pyne  SupOrg_00219654
# 1282                   Finance      Steven Zabel  SupOrg_00218043
# 34087   Unum US Client Success       Liz Rickett  SupOrg_00216968
#
#                                           OrgLevel05 OrgLevel05Manager  \
# Emplid
# 32773                                            NaN               NaN
# 30477                         Real Estate Management   Richard Meadows
# 586                            National Client Group         John King
# 1282                Transformation Management Office  Stephen Mitchell
# 34087   Unum US IDI Policy & Practice, Training & QR   Jennifer Robare
#
#            OrgLevel06ID                       OrgLevel06 OrgLevel06Manager  \
# Emplid
# 32773               NaN                              NaN               NaN
# 30477   SupOrg_00300120  Global Services Print & Distrib   Richard Meadows
# 586                 NaN                              NaN               NaN
# 1282      SupOrg_102324                 TMO Organization    Sandra Sincero
# 34087   SupOrg_00217735      Unum US IDI Policy Services  Linda Belezarian
#
#            OrgLevel07ID                                         OrgLevel07  \
# Emplid
# 32773               NaN                                                NaN
# 30477   SupOrg_00116642                    Global Services Print & Distrib
# 586                 NaN                                                NaN
# 1282    SupOrg_00117136  Enterprise Finance Operational Reporting & Ana...
# 34087               NaN                                                NaN
#
#        OrgLevel07Manager OrgLevel08ID OrgLevel08 OrgLevel08Manager  \
# Emplid
# 32773                NaN          NaN        NaN               NaN
# 30477    Richard Meadows          NaN        NaN               NaN
# 586                  NaN          NaN        NaN               NaN
# 1282    Pamela Carpenter          NaN        NaN               NaN
# 34087                NaN          NaN        NaN               NaN
#
#        OrgLevel09ID OrgLevel09 OrgLevel09Manager  OrgLevel10ID  OrgLevel10  \
# Emplid
# 32773           NaN        NaN               NaN           NaN         NaN
# 30477           NaN        NaN               NaN           NaN         NaN
# 586             NaN        NaN               NaN           NaN         NaN
# 1282            NaN        NaN               NaN           NaN         NaN
# 34087           NaN        NaN               NaN           NaN         NaN
#
#         OrgLevel10Manager         Manager_Location  \
# Emplid
# 32773                 NaN  Chattanooga Home Office
# 30477                 NaN  Chattanooga Home Office
# 586                   NaN     Portland Home Office
# 1282                  NaN     Portland Home Office
# 34087                 NaN         Home Worker - US
#
#                                   Supervisory_Org_L1_Away  \
# Emplid
# 32773                          Unum Group (Rick McKenney)
# 30477   Global Services Print & Distrib (Richard Meado...
# 586                      Unum Group Benefits (Chris Pyne)
# 1282                    TMO Organization (Sandra Sincero)
# 34087   Unum US IDI Policy & Practice, Training & QR (...
#
#                                   Supervisory_Org_L2_Away  \
# Emplid
# 32773                      Unum Executive (Rick McKenney)
# 30477            Real Estate Management (Richard Meadows)
# 586                      Unum Group COO (Michael Simonds)
# 1282    Transformation Management Office (Stephen Mitc...
# 34087                Unum US Client Success (Liz Rickett)
#
#                   Supervisory_Org_L3_Away            Supervisory_Org_L4_Away  \
# Emplid
# 32773                                 NaN                                NaN
# 30477   Corporate Services (Wendy Gibson)   Unum Law & Audit (Lisa Iglesias)
# 586            Unum Group (Rick McKenney)     Unum Executive (Rick McKenney)
# 1282               Finance (Steven Zabel)  Enterprise Finance (Steven Zabel)
# 34087    Unum Group COO (Michael Simonds)         Unum Group (Rick McKenney)
#
#                Supervisory_Org_L5_Away         Supervisory_Org_L6_Away  \
# Emplid
# 32773                              NaN                             NaN
# 30477       Unum Group (Rick McKenney)  Unum Executive (Rick McKenney)
# 586                                NaN                             NaN
# 1282        Unum Group (Rick McKenney)  Unum Executive (Rick McKenney)
# 34087   Unum Executive (Rick McKenney)                             NaN
#
#        Supervisory_Org_L7_Away Supervisory_Org_L8_Away  \
# Emplid
# 32773                      NaN                     NaN
# 30477                      NaN                     NaN
# 586                        NaN                     NaN
# 1282                       NaN                     NaN
# 34087                      NaN                     NaN
#
#         Supervisory_Org_L9_Away  Supervisory_Org_L10_Away  \
# Emplid
# 32773                       NaN                       NaN
# 30477                       NaN                       NaN
# 586                         NaN                       NaN
# 1282                        NaN                       NaN
# 34087                       NaN                       NaN
#
#        Worker_Supervisory_Org_L1 Worker_Supervisory_Org_L2  \
# Emplid
# 32773                        NaN                       NaN
# 30477                        NaN                       NaN
# 586                          NaN                       NaN
# 1282                         NaN                       NaN
# 34087                        NaN                       NaN
#
#        Worker_Supervisory_Org_L3 Worker_Supervisory_Org_L4  \
# Emplid
# 32773                        NaN                       NaN
# 30477                        NaN                       NaN
# 586                          NaN                       NaN
# 1282                         NaN                       NaN
# 34087                        NaN                       NaN
#
#        Worker_Supervisory_Org_L5 Worker_Supervisory_Org_L6  \
# Emplid
# 32773                        NaN                       NaN
# 30477                        NaN                       NaN
# 586                          NaN                       NaN
# 1282                         NaN                       NaN
# 34087                        NaN                       NaN
#
#        Worker_Supervisory_Org_L7 Worker_Supervisory_Org_L8  \
# Emplid
# 32773                        NaN                       NaN
# 30477                        NaN                       NaN
# 586                          NaN                       NaN
# 1282                         NaN                       NaN
# 34087                        NaN                       NaN
#
#        Worker_Supervisory_Org_L9  Worker_Supervisory_Org_L10
# Emplid
# 32773                        NaN                         NaN
# 30477                        NaN                         NaN
# 586                          NaN                         NaN
# 1282                         NaN                         NaN
# 34087                        NaN                         NaN

# %%
recordstart = '2020-01-01'
recordend = '2020-06-30'

# %%
turnover2 = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Trended_Worker_Turnover_Details?IncludeSubOrgs=1&Active=0&Record_Start={0}-08%3A00&Remove_Exclude_From_HC=0&Record_End={1}-08%3A00&SupervisoryOrg%21WID=fad8c8a44c4510541494e34161d00311&format=csv'.format(recordstart,recordend)
with requests.Session() as s:
    download = s.get(turnover2, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    turnover2 = pd.read_csv(io.StringIO(decoded_content))
    turnover2 = turnover2.set_index('Emplid')
# Out:
# C:\Users\DDY17\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11,12,13,14,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(turnover2.shape)
turnover2.head()
# Out:
# (86903, 143)
#        Year-Quarter  Month Record_Date Record_Type   LAN_ID  Preferred_Name  \
# Emplid
# 32489       2020-Q1      1  2020-01-01    Activity  #ADAUMT    Marty Turner
# 38583       2020-Q1      1  2020-01-01    Activity    AYP18   Callum Aitken
# 89147       2020-Q1      1  2020-01-01    Activity    B6F15  Kelli Abramson
# 55538       2020-Q1      1  2020-01-01    Activity    CNZ04     Jacki Grano
# 42940       2020-Q1      1  2020-01-01    Activity  #SPRMRW    Rachel Woods
#
#                              Worker                  Work_Email        Hire  \
# Emplid
# 32489     Marty Turner (Terminated)        martyturner@unum.com  1974-09-10
# 38583                 Callum Aitken    Callum.AITKEN@unum.co.uk  2018-04-03
# 89147   Kelli Abramson (Terminated)  KAbramson@ColonialLife.com  2015-11-23
# 55538      Jacki Grano (Terminated)             JGrano@UNUM.COM  2004-04-15
# 42940     Rachel Woods (Terminated)             rwoods@unum.com  2000-05-01
#
#        OriginalHireAtRecordDate          Term_Event Term_Category Term_Reason  \
# Emplid
# 32489                1974-09-10  Terminate Employee     Voluntary  Retirement
# 38583                2003-10-27                 NaN           NaN         NaN
# 89147                2015-11-23  Terminate Employee     Voluntary    Personal
# 55538                2004-04-15  Terminate Employee     Voluntary  Retirement
# 42940                2000-05-01  Terminate Employee     Voluntary  Retirement
#
#        Secondary_Term_Reason  Is_Term_90-Day  Is_Term_New_Hire  \
# Emplid
# 32489                    NaN               0                 0
# 38583                    NaN               0                 0
# 89147                    NaN               0                 0
# 55538                    NaN               0                 0
# 42940                    NaN               0                 0
#
#        Is_Rehire_Eligible         Tenure  Years_of_Service    Age_Group  Age  \
# Emplid
# 32489                  No      25+ Years             45.31  60 and over   63
# 38583                 NaN  01 - 02 Years              1.74      40 - 44   40
# 89147                 NaN  02 - 05 Years              4.11      25 - 29   29
# 55538                 Yes  15 - 20 Years             15.71  60 and over   65
# 42940                 NaN  15 - 20 Years             19.67  60 and over   81
#
#         Diverse  Gender Gender_Identity Sexual_Orientation Pronoun  \
# Emplid
# 32489         1  Female             NaN                NaN     NaN
# 38583         0    Male             NaN                NaN     NaN
# 89147         1  Female             NaN                NaN     NaN
# 55538         1  Female             NaN                NaN     NaN
# 42940         1  Female             NaN                NaN     NaN
#
#                                 Ethnicity  Hispanic_Latino  Minority  \
# Emplid
# 32489    White (United States of America)                0         0
# 38583   White (United Kingdom) (inactive)                0         0
# 89147    White (United States of America)                0         0
# 55538    White (United States of America)                0         0
# 42940    White (United States of America)                0         0
#
#        MinorityStatus  Disability DisabilityStatus Disability_Self_ID  \
# Emplid
# 32489    Non-Minority           0              NaN                NaN
# 38583    Non-Minority           0              NaN                NaN
# 89147    Non-Minority           0              NaN                NaN
# 55538    Non-Minority           0              NaN                NaN
# 42940    Non-Minority           0              NaN                NaN
#
#         Veteran VeteranStatus MilitaryStatus Highest_Degree  On_Leave  Active  \
# Emplid
# 32489         0           NaN            NaN            NaN         0       0
# 38583         0           NaN            NaN      Bachelors         0       1
# 89147         0           NaN            NaN            NaN         0       0
# 55538         0           NaN            NaN            NaN         0       0
# 42940         0           NaN            NaN            NaN         0       0
#
#                 Management_Level                                  Job_Level  \
# Emplid
# 32489   5 Individual Contributor  5.2 Professional - Individual Contributor
# 38583   5 Individual Contributor  5.2 Professional - Individual Contributor
# 89147                   2 Leader                                 3 Managers
# 55538               3 Management                                2 Directors
# 42940   5 Individual Contributor                              6 Entry-Level
#
#               Job_Family_Group                   Job_Family   Job_Code  \
# Emplid
# 32489   Information Technology  Information Technology Jobs  IT792-USA
# 38583                      NaN            Customer Services   SC042-UK
# 89147                      NaN            Customer Services  DI396-USA
# 55538   Information Technology  Information Technology Jobs  IT821-USA
# 42940                      NaN          Operational Support  CC816-USA
#
#                                 Job_Profile             Business_Title  \
# Emplid
# 32489                   Test Engineer I, US                        NaN
# 38583    Broker Services, Senior Specialist  Claim Management Spec III
# 89147   National Recruiting Program Manager                        NaN
# 55538             Director, IT Delivery, US                        NaN
# 42940           Intake Service Specialist I                        NaN
#
#         YearsInJobAtRecordDate Years_In_Job                       Time_in_Job  \
# Emplid
# 32489                     4.66  05-10 Years  4 year(s), 7 month(s), 28 day(s)
# 38583                     0.00  01-02 Years  0 year(s), 5 month(s), 30 day(s)
# 89147                     0.74  01-02 Years  0 year(s), 8 month(s), 24 day(s)
# 55538                     1.08  02-05 Years  1 year(s), 0 month(s), 29 day(s)
# 42940                     2.02  02-05 Years   2 year(s), 0 month(s), 7 day(s)
#
#         Position_ID Grade  Annual_Salary  Annual_FTE_Salary  \
# Emplid
# 32489           NaN    11       62603.00            62603.0
# 38583      312548.0     9       35757.54            27300.0
# 89147           NaN    12       78000.00            78000.0
# 55538           NaN    14      112229.00           112229.0
# 42940           NaN     5       31200.00            31200.0
#
#         Salary_Range_Minimum  Salary_Range_Midpoint  Salary_Range_Maximum  \
# Emplid
# 32489                  56600            82071.36000                107500
# 38583                  20000            26000.00000                 32000
# 89147                  60100            81100.00000                102200
# 55538                  96100           141819.31008                187400
# 42940                  31200            37400.00000                 43600
#
#         Is_Org_Manager  Is_People_Manager  Direct_Reports  FTE  Exempt  \
# Emplid
# 32489                0                  0               0  1.0       1
# 38583                0                  0               0  1.0       0
# 89147                0                  0               0  1.0       1
# 55538                1                  0               0  1.0       1
# 42940                0                  0               0  1.0       0
#
#        Full_Part_Time Worker_Type Employee_Type Contingent_Type    Potential  \
# Emplid
# 32489       Full time    Employee       Regular             NaN  Well Placed
# 38583       Full time    Employee       Regular             NaN          NaN
# 89147       Full time    Employee       Regular             NaN  Well Placed
# 55538       Full time    Employee       Regular             NaN  Well Placed
# 42940       Full time    Employee       Regular             NaN  Well Placed
#
#                                             Company                   Country  \
# Emplid
# 32489                              C3035 Unum Group  United States of America
# 38583   C5094 Unum European Holding Company Limited            United Kingdom
# 89147                              C3035 Unum Group  United States of America
# 55538                              C3035 Unum Group  United States of America
# 42940                              C3035 Unum Group  United States of America
#
#                    Campus                   Location Work_Address_State  \
# Emplid
# 32489         Chattanooga    Chattanooga Home Office                NaN
# 38583             Dorking                    Dorking             Surrey
# 89147            Columbia  Colonial Life Home Office                NaN
# 55538            Portland       Portland Home Office                NaN
# 42940   Home Workers - US           Home Worker - US          Tennessee
#
#                  Business_Area             Profile_Area  \
# Emplid
# 32489   Information Technology         Information Tech
# 38583                  Unum UK           Unum UK Direct
# 89147            US Operations            Colonial Life
# 55538   Information Technology         Information Tech
# 42940            US Operations  Unum US Benefits Center
#
#                           Department               Consolidated_Area  \
# Emplid
# 32489                    Colonial IT                          CLA IT
# 38583      Unum UK Customer Services                 Broker Services
# 89147                      CLA Sales        Distribution Development
# 55538                  Office Of CTO             Infrastructure - IT
# 42940   Unum US Benefits AMC and CEC  UUS Customer Experience Center
#
#                           Area               Sub_Area Cost_Center_ID  \
# Emplid
# 32489         Product Tech CLA  US - CLA Product Tech         EC1794
# 38583          Broker_Services              Regional.         EC7026
# 89147      National_Recruiting       Recruiting_Teams         EC6231
# 55538             Infra - DICE           DICE Staff_2         EC9080
# 42940   UUS Cust & Ben Support            Unum Intake         EC8774
#
#        Cost_Center            BP_Type  End_Headcount  Hires  Promotion  \
# Emplid
# 32489          NaN        Termination              0      0          0
# 38583       Claims  Transfer Employee              0      0          0
# 89147          NaN        Termination              0      0          0
# 55538          NaN        Termination              0      0          0
# 42940          NaN        Termination              0      0          0
#
#         Transfer_Out  Transfer_In  Termination  Voluntary_Termination  \
# Emplid
# 32489              0            0            1                      1
# 38583              1            0            0                      0
# 89147              0            0            1                      1
# 55538              0            0            1                      1
# 42940              0            0            1                      1
#
#         Involuntary_Termination SupervisoryOrgID  \
# Emplid
# 32489                         0  SupOrg_00289511
# 38583                         0  SupOrg_00051422
# 89147                         0  SupOrg_00200312
# 55538                         0  SupOrg_00303218
# 42940                         0  SupOrg_00116902
#
#                              SupervisoryOrg         OrgManager  OrgLevel  \
# Emplid
# 32489             CLA: Product Value Stream      David Bateman         6
# 38583                    UK Broker Services  Michelle Garfield         8
# 89147       Colonial Life Field Development     Jennifer Davis         7
# 55538                     End User Services        Blake Pease         5
# 42940   Unum US Customer & Benefits Support        Lissa Lewis         7
#
#             OrgLevel01ID      OrgLevel01 OrgLevel01Manager     OrgLevel02ID  \
# Emplid
# 32489   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 38583   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 89147   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 55538   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 42940   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
#
#         OrgLevel02 OrgLevel02Manager     OrgLevel03ID  \
# Emplid
# 32489   Unum Group     Rick McKenney  SupOrg_00300846
# 38583   Unum Group     Rick McKenney  SupOrg_00112942
# 89147   Unum Group     Rick McKenney  SupOrg_00112942
# 55538   Unum Group     Rick McKenney  SupOrg_00300846
# 42940   Unum Group     Rick McKenney  SupOrg_00112942
#
#                            OrgLevel03 OrgLevel03Manager     OrgLevel04ID  \
# Emplid
# 32489   Technology and Transformation     Puneet Bhasin  SupOrg_00302588
# 38583                  Unum Group COO   Michael Simonds  SupOrg_00051934
# 89147                  Unum Group COO   Michael Simonds  SupOrg_00210462
# 55538   Technology and Transformation     Puneet Bhasin  SupOrg_00302588
# 42940                  Unum Group COO   Michael Simonds  SupOrg_00309192
#
#                                                OrgLevel04 OrgLevel04Manager  \
# Emplid
# 32489                              Information Technology        Gautam Roy
# 38583                                  Unum International         Mark Till
# 89147                                  VB & Colonial Life        Tim Arnold
# 55538                              Information Technology        Gautam Roy
# 42940   Customer Experience Center/Absence Management ...  Michelle Boucher
#
#            OrgLevel05ID                  OrgLevel05 OrgLevel05Manager  \
# Emplid
# 32489   SupOrg_00307100          Data and Analytics  Apparsamy Balaji
# 38583   SupOrg_00293589   Unum UK Customer Services        Liz Walker
# 89147   SupOrg_00221275  Field & Market Development   Richard Shaffer
# 55538   SupOrg_00303218           End User Services       Blake Pease
# 42940   SupOrg_00219796          US Contact Centers    Preston Rogers
#
#            OrgLevel06ID                            OrgLevel06  \
# Emplid
# 32489   SupOrg_00289511             CLA: Product Value Stream
# 38583   SupOrg_00220960                    UK Broker Services
# 89147   SupOrg_00213998  Colonial Life Sales Mgmt Performance
# 55538               NaN                                   NaN
# 42940     SupOrg_312004   Unum US Customer & Benefits Support
#
#        OrgLevel06Manager     OrgLevel07ID  \
# Emplid
# 32489      David Bateman              NaN
# 38583    James Vallender  SupOrg_00303502
# 89147     Michelle White  SupOrg_00200312
# 55538                NaN              NaN
# 42940        Liz DiSotto  SupOrg_00116902
#
#                                  OrgLevel07 OrgLevel07Manager  \
# Emplid
# 32489                                   NaN               NaN
# 38583                    UK Broker Services  Karen Blatchford
# 89147       Colonial Life Field Development    Jennifer Davis
# 55538                                   NaN               NaN
# 42940   Unum US Customer & Benefits Support       Lissa Lewis
#
#            OrgLevel08ID          OrgLevel08  OrgLevel08Manager OrgLevel09ID  \
# Emplid
# 32489               NaN                 NaN                NaN          NaN
# 38583   SupOrg_00051422  UK Broker Services  Michelle Garfield          NaN
# 89147               NaN                 NaN                NaN          NaN
# 55538               NaN                 NaN                NaN          NaN
# 42940               NaN                 NaN                NaN          NaN
#
#        OrgLevel09 OrgLevel09Manager  OrgLevel10ID  OrgLevel10  \
# Emplid
# 32489         NaN               NaN           NaN         NaN
# 38583         NaN               NaN           NaN         NaN
# 89147         NaN               NaN           NaN         NaN
# 55538         NaN               NaN           NaN         NaN
# 42940         NaN               NaN           NaN         NaN
#
#         OrgLevel10Manager           Manager_Location  \
# Emplid
# 32489                 NaN  Colonial Life Home Office
# 38583                 NaN                    Dorking
# 89147                 NaN  Colonial Life Home Office
# 55538                 NaN       Portland Home Office
# 42940                 NaN       Portland Home Office
#
#                                   Supervisory_Org_L1_Away  \
# Emplid
# 32489               Data and Analytics (Apparsamy Balaji)
# 38583               UK Broker Services (Karen Blatchford)
# 89147   Colonial Life Sales Mgmt Performance (Michelle...
# 55538                 Information Technology (Gautam Roy)
# 42940   Unum US Customer & Benefits Support (Liz DiSotto)
#
#                               Supervisory_Org_L2_Away  \
# Emplid
# 32489             Information Technology (Gautam Roy)
# 38583            UK Broker Services (James Vallender)
# 89147    Field & Market Development (Richard Shaffer)
# 55538   Technology and Transformation (Puneet Bhasin)
# 42940             US Contact Centers (Preston Rogers)
#
#                                   Supervisory_Org_L3_Away  \
# Emplid
# 32489       Technology and Transformation (Puneet Bhasin)
# 38583              Unum UK Customer Services (Liz Walker)
# 89147                     VB & Colonial Life (Tim Arnold)
# 55538                          Unum Group (Rick McKenney)
# 42940   Customer Experience Center/Absence Management ...
#
#                  Supervisory_Org_L4_Away           Supervisory_Org_L5_Away  \
# Emplid
# 32489         Unum Group (Rick McKenney)    Unum Executive (Rick McKenney)
# 38583     Unum International (Mark Till)  Unum Group COO (Michael Simonds)
# 89147   Unum Group COO (Michael Simonds)        Unum Group (Rick McKenney)
# 55538     Unum Executive (Rick McKenney)                               NaN
# 42940   Unum Group COO (Michael Simonds)        Unum Group (Rick McKenney)
#
#                Supervisory_Org_L6_Away         Supervisory_Org_L7_Away  \
# Emplid
# 32489                              NaN                             NaN
# 38583       Unum Group (Rick McKenney)  Unum Executive (Rick McKenney)
# 89147   Unum Executive (Rick McKenney)                             NaN
# 55538                              NaN                             NaN
# 42940   Unum Executive (Rick McKenney)                             NaN
#
#        Supervisory_Org_L8_Away  Supervisory_Org_L9_Away  \
# Emplid
# 32489                      NaN                      NaN
# 38583                      NaN                      NaN
# 89147                      NaN                      NaN
# 55538                      NaN                      NaN
# 42940                      NaN                      NaN
#
#         Supervisory_Org_L10_Away       Worker_Supervisory_Org_L1  \
# Emplid
# 32489                        NaN                             NaN
# 38583                        NaN  Unum Executive (Rick McKenney)
# 89147                        NaN                             NaN
# 55538                        NaN                             NaN
# 42940                        NaN                             NaN
#
#          Worker_Supervisory_Org_L2         Worker_Supervisory_Org_L3  \
# Emplid
# 32489                          NaN                               NaN
# 38583   Unum Group (Rick McKenney)  Unum Group COO (Michael Simonds)
# 89147                          NaN                               NaN
# 55538                          NaN                               NaN
# 42940                          NaN                               NaN
#
#              Worker_Supervisory_Org_L4  \
# Emplid
# 32489                              NaN
# 38583   Unum International (Mark Till)
# 89147                              NaN
# 55538                              NaN
# 42940                              NaN
#
#                      Worker_Supervisory_Org_L5  \
# Emplid
# 32489                                      NaN
# 38583   Unum UK Customer Services (Liz Walker)
# 89147                                      NaN
# 55538                                      NaN
# 42940                                      NaN
#
#                              Worker_Supervisory_Org_L6  \
# Emplid
# 32489                                              NaN
# 38583   Claims Rehab & Medical Services (Paula Coffey)
# 89147                                              NaN
# 55538                                              NaN
# 42940                                              NaN
#
#        Worker_Supervisory_Org_L7                  Worker_Supervisory_Org_L8  \
# Emplid
# 32489                        NaN                                        NaN
# 38583      Claims (Sarah Gilbey)  UK Customer Care Services (Nicola Ansell)
# 89147                        NaN                                        NaN
# 55538                        NaN                                        NaN
# 42940                        NaN                                        NaN
#
#        Worker_Supervisory_Org_L9  Worker_Supervisory_Org_L10
# Emplid
# 32489                        NaN                         NaN
# 38583                        NaN                         NaN
# 89147                        NaN                         NaN
# 55538                        NaN                         NaN
# 42940                        NaN                         NaN

# %%
recordstart = '2020-07-01'
recordend = '2020-12-31'

# %%
turnover3 = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Trended_Worker_Turnover_Details?IncludeSubOrgs=1&Active=0&Record_Start={0}-08%3A00&Remove_Exclude_From_HC=0&Record_End={1}-08%3A00&SupervisoryOrg%21WID=fad8c8a44c4510541494e34161d00311&format=csv'.format(recordstart,recordend)
with requests.Session() as s:
    download = s.get(turnover3, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    turnover3 = pd.read_csv(io.StringIO(decoded_content))
    turnover3 = turnover3.set_index('Emplid')
# Out:
# C:\Users\DDY17\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11,12,13,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(turnover3.shape)
turnover3.head()
# Out:
# (83721, 143)
#        Year-Quarter  Month Record_Date Record_Type LAN_ID  Preferred_Name  \
# Emplid
# 74928       2020-Q3      7  2020-07-01    Activity  GDX13  Andrew Philips
# 9327        2020-Q3      7  2020-07-01    Activity  C5S2M        Sara May
# 21204       2020-Q3      7  2020-07-01    Activity  C9LMM     Mike Miller
# 33490       2020-Q3      7  2020-07-01    Activity  C0MXK     Mike Keller
# 89973       2020-Q3      7  2020-07-01    Activity  ATA16     David Allen
#
#                           Worker                 Work_Email        Hire  \
# Emplid
# 74928             Andrew Philips  Andrew.PHILIPS@unum.co.uk  2013-07-15
# 9327       Sara May (Terminated)              smay@unum.com  1996-04-29
# 21204   Mike Miller (Terminated)  lmmiller@coloniallife.com  1976-03-01
# 33490   Mike Keller (Terminated)  MLKeller@ColonialLife.com  1988-02-11
# 89973   David Allen (Terminated)           DALLEN1@UNUM.com  2016-05-23
#
#        OriginalHireAtRecordDate          Term_Event  \
# Emplid
# 74928                2013-07-15                 NaN
# 9327                 1996-04-29  Terminate Employee
# 21204                1976-03-01  Terminate Employee
# 33490                1988-02-11  Terminate Employee
# 89973                2016-05-23  Terminate Employee
#
#                      Term_Category     Term_Reason Secondary_Term_Reason  \
# Emplid
# 74928                          NaN             NaN                   NaN
# 9327                     Voluntary      Retirement                   NaN
# 21204   Job Elimination/Redundancy    No Placement                   NaN
# 33490                    Voluntary      Retirement                   NaN
# 89973                    Voluntary  Other Position                   NaN
#
#         Is_Term_90-Day  Is_Term_New_Hire Is_Rehire_Eligible         Tenure  \
# Emplid
# 74928                0                 0                NaN  05 - 10 Years
# 9327                 0                 0                Yes  20 - 24 Years
# 21204                0                 0                 No      25+ Years
# 33490                0                 0                NaN      25+ Years
# 89973                0                 0                NaN  02 - 05 Years
#
#         Years_of_Service    Age_Group  Age  Diverse  Gender Gender_Identity  \
# Emplid
# 74928               6.96      25 - 29   29        0    Male             NaN
# 9327               24.17  60 and over   65        1  Female             NaN
# 21204              44.33  60 and over   66        0    Male             NaN
# 33490              32.39  60 and over   63        0    Male             NaN
# 89973               4.10      25 - 29   28        0    Male             NaN
#
#        Sexual_Orientation Pronoun                          Ethnicity  \
# Emplid
# 74928                 NaN     NaN  White (United Kingdom) (inactive)
# 9327                  NaN     NaN   White (United States of America)
# 21204                 NaN     NaN   White (United States of America)
# 33490                 NaN     NaN   White (United States of America)
# 89973                 NaN     NaN   White (United States of America)
#
#         Hispanic_Latino  Minority MinorityStatus  Disability DisabilityStatus  \
# Emplid
# 74928                 0         0   Non-Minority           0              NaN
# 9327                  0         0   Non-Minority           0              NaN
# 21204                 0         0   Non-Minority           0              NaN
# 33490                 0         0   Non-Minority           0              NaN
# 89973                 0         0   Non-Minority           0              NaN
#
#                    Disability_Self_ID  Veteran VeteranStatus MilitaryStatus  \
# Emplid
# 74928                             NaN        0           NaN            NaN
# 9327                              NaN        0           NaN            NaN
# 21204   NO, I DON'T HAVE A DISABILITY        0           NaN            NaN
# 33490                             NaN        0           NaN            NaN
# 89973                             NaN        0           NaN            NaN
#
#        Highest_Degree  On_Leave  Active          Management_Level  \
# Emplid
# 74928             NaN         0       1  5 Individual Contributor
# 9327            Other         0       0  5 Individual Contributor
# 21204       Bachelors         0       0           1 Senior Leader
# 33490       Bachelors         0       0           1 Senior Leader
# 89973       Bachelors         0       0  5 Individual Contributor
#
#                                         Job_Level        Job_Family_Group  \
# Emplid
# 74928   5.2 Professional - Individual Contributor                     NaN
# 9327    5.2 Professional - Individual Contributor                     NaN
# 21204                         1.3 VP & Equivalent                     NaN
# 33490                         1.3 VP & Equivalent                     NaN
# 89973   5.2 Professional - Individual Contributor  Information Technology
#
#                          Job_Family   Job_Code  \
# Emplid
# 74928             Customer Services   SC043-UK
# 9327                         Claims  CC888-USA
# 21204             Customer Services  DI238-USA
# 33490            Sales (Incentives)  SA242-USA
# 89973   Information Technology Jobs  IT790-USA
#
#                                               Job_Profile  \
# Emplid
# 74928                    Broker Services, Lead Specialist
# 9327                             Sr. Benefits Coordinator
# 21204   VP, Sales Compensation, Incentives & Support (...
# 33490                           VP, Sales, CL - Southwest
# 89973                             Software Engineer I, US
#
#                   Business_Title  YearsInJobAtRecordDate Years_In_Job  \
# Emplid
# 74928   Financial Analyst - FP&A                    0.00  00-01 Years
# 9327                         NaN                    0.54  01-02 Years
# 21204                        NaN                    7.49  05-10 Years
# 33490                        NaN                   13.82  10-15 Years
# 89973                        NaN                    2.71  02-05 Years
#
#                               Time_in_Job  Position_ID Grade  Annual_Salary  \
# Emplid
# 74928    4 year(s), 2 month(s), 29 day(s)     317664.0    10       39804.54
# 9327     0 year(s), 6 month(s), 15 day(s)          NaN     8       25063.50
# 21204    7 year(s), 5 month(s), 29 day(s)          NaN    16      200000.00
# 33490   13 year(s), 9 month(s), 29 day(s)          NaN    17      254300.00
# 89973    2 year(s), 8 month(s), 15 day(s)          NaN    11       68071.00
#
#         Annual_FTE_Salary  Salary_Range_Minimum  Salary_Range_Midpoint  \
# Emplid
# 74928             31775.0                 24100               32000.00
# 9327             100254.0                 33300               44089.92
# 21204            200000.0                132700              182500.00
# 33490            254300.0                     0                   0.00
# 89973             68071.0                 56600               82071.36
#
#         Salary_Range_Maximum  Is_Org_Manager  Is_People_Manager  \
# Emplid
# 74928                  39900               0                  0
# 9327                   54900               0                  0
# 21204                 232200               0                  0
# 33490                      0               1                  0
# 89973                 107500               0                  0
#
#         Direct_Reports  FTE  Exempt Full_Part_Time Worker_Type Employee_Type  \
# Emplid
# 74928                0  1.0       0      Full time    Employee       Regular
# 9327                 0  0.5       0      Part time    Employee       Regular
# 21204                0  1.0       1      Full time    Employee       Regular
# 33490                0  1.0       1      Full time    Employee       Regular
# 89973                0  1.0       1      Full time    Employee       Regular
#
#        Contingent_Type                            Potential  \
# Emplid
# 74928              NaN                                  NaN
# 9327               NaN                                  NaN
# 21204              NaN                          Well Placed
# 33490              NaN  High Impact Leader at Current Level
# 89973              NaN           Likely in Wrong Role/Level
#
#                                             Company                   Country  \
# Emplid
# 74928   C5094 Unum European Holding Company Limited            United Kingdom
# 9327                               C3035 Unum Group  United States of America
# 21204                              C3035 Unum Group  United States of America
# 33490                              C3035 Unum Group  United States of America
# 89973                              C3035 Unum Group  United States of America
#
#                   Campus                   Location Work_Address_State  \
# Emplid
# 74928        Basingstoke                Basingstoke             Surrey
# 9327            Portland       Portland Home Office                NaN
# 21204           Columbia  Colonial Life Home Office                NaN
# 33490   US Sales Offices          Plano Sales - CLA                NaN
# 89973        Chattanooga    Chattanooga Home Office                NaN
#
#                  Business_Area             Profile_Area  \
# Emplid
# 74928                  Unum UK           Unum UK Direct
# 9327             US Operations  Unum US Benefits Center
# 21204            US Operations            Colonial Life
# 33490            US Operations            Colonial Life
# 89973   Information Technology         Information Tech
#
#                             Department  \
# Emplid
# 74928        Unum UK Customer Services
# 9327       Unum US Benefits Operations
# 21204   CLA Growth and Risk Operations
# 33490                        CLA Sales
# 89973                    Office Of CTO
#
#                                         Consolidated_Area  \
# Emplid
# 74928                                     Broker Services
# 9327                              LTC Benefits Operations
# 21204   Growth & Risk Ops Support, Reporting and Compl...
# 33490                                       Sales Offices
# 89973                                 Benefits Technology
#
#                                       Area                    Sub_Area  \
# Emplid
# 74928                      Broker_Services                  Brkr Srvcs
# 9327                      LTC Benefits Ops     Long-Term Care Benefits
# 21204            Growth and Risk Ops Admin    Grwth and Risk Ops Admin
# 33490   TSM Sales Offices Southwest Region  SW Territory Sales Offices
# 89973                         UUS Benefits           US - UUS Benefits
#
#        Cost_Center_ID          Cost_Center            BP_Type  End_Headcount  \
# Emplid
# 74928          EC7054  Strategy & Planning  Transfer Employee              0
# 9327           EC8418                  NaN        Termination              0
# 21204          EC6088                  NaN        Termination              0
# 33490          EC6256                  NaN        Termination              0
# 89973          EC1700                  NaN        Termination              0
#
#         Hires  Promotion  Transfer_Out  Transfer_In  Termination  \
# Emplid
# 74928       0          0             1            0            0
# 9327        0          0             0            0            1
# 21204       0          0             0            0            1
# 33490       0          0             0            0            1
# 89973       0          0             0            0            1
#
#         Voluntary_Termination  Involuntary_Termination SupervisoryOrgID  \
# Emplid
# 74928                       0                        0  SupOrg_00310439
# 9327                        1                        0  SupOrg_00208156
# 21204                       0                        1  SupOrg_00284224
# 33490                       1                        0  SupOrg_00210487
# 89973                       1                        0  SupOrg_00289610
#
#                               SupervisoryOrg       OrgManager  OrgLevel  \
# Emplid
# 74928                     UK Broker Services  Marie Sheffield         8
# 9327    Closed Block LTC Benefits Operations       Jon Colson         8
# 21204        Colonial Life Growth Operations       Tim Arnold         5
# 33490                    Colonial Life Sales   William Deehan         5
# 89973                          Benefits Tech  Daniela LaCelle         6
#
#             OrgLevel01ID      OrgLevel01 OrgLevel01Manager     OrgLevel02ID  \
# Emplid
# 74928   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 9327    SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 21204   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 33490   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 89973   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
#
#         OrgLevel02 OrgLevel02Manager     OrgLevel03ID  \
# Emplid
# 74928   Unum Group     Rick McKenney  SupOrg_00112942
# 9327    Unum Group     Rick McKenney  SupOrg_00112942
# 21204   Unum Group     Rick McKenney  SupOrg_00112942
# 33490   Unum Group     Rick McKenney  SupOrg_00112942
# 89973   Unum Group     Rick McKenney  SupOrg_00300846
#
#                            OrgLevel03 OrgLevel03Manager     OrgLevel04ID  \
# Emplid
# 74928                  Unum Group COO   Michael Simonds  SupOrg_00051934
# 9327                   Unum Group COO   Michael Simonds  SupOrg_00216660
# 21204                  Unum Group COO   Michael Simonds  SupOrg_00210462
# 33490                  Unum Group COO   Michael Simonds  SupOrg_00210462
# 89973   Technology and Transformation     Puneet Bhasin  SupOrg_00302588
#
#                          OrgLevel04 OrgLevel04Manager     OrgLevel05ID  \
# Emplid
# 74928            Unum International         Mark Till  SupOrg_00293589
# 9327    Unum US Benefits Operations       Lori Whynot  SupOrg_00117105
# 21204            VB & Colonial Life        Tim Arnold  SupOrg_00284224
# 33490            VB & Colonial Life        Tim Arnold  SupOrg_00210487
# 89973        Information Technology        Gautam Roy  SupOrg_00320123
#
#                                    OrgLevel05 OrgLevel05Manager  \
# Emplid
# 74928               Unum UK Customer Services        Liz Walker
# 9327        Unum US Group Life & LTC Benefits    Michelle Bryer
# 21204         Colonial Life Growth Operations        Tim Arnold
# 33490                     Colonial Life Sales    William Deehan
# 89973   Benefit & Contact Center Journey Tech     Mike Schubert
#
#            OrgLevel06ID                            OrgLevel06  \
# Emplid
# 74928   SupOrg_00220960                    UK Broker Services
# 9327    SupOrg_00294234  Closed Block LTC Benefits Operations
# 21204               NaN                                   NaN
# 33490               NaN                                   NaN
# 89973   SupOrg_00289610                         Benefits Tech
#
#        OrgLevel06Manager     OrgLevel07ID  \
# Emplid
# 74928    James Vallender  SupOrg_00303500
# 9327     Stephanie Perry  SupOrg_00214191
# 21204                NaN              NaN
# 33490                NaN              NaN
# 89973    Daniela LaCelle              NaN
#
#                                   OrgLevel07 OrgLevel07Manager  \
# Emplid
# 74928                     UK Broker Services    Louise Cauchie
# 9327    Closed Block LTC Benefits Operations        John Noble
# 21204                                    NaN               NaN
# 33490                                    NaN               NaN
# 89973                                    NaN               NaN
#
#            OrgLevel08ID                            OrgLevel08  \
# Emplid
# 74928   SupOrg_00310439                    UK Broker Services
# 9327    SupOrg_00208156  Closed Block LTC Benefits Operations
# 21204               NaN                                   NaN
# 33490               NaN                                   NaN
# 89973               NaN                                   NaN
#
#        OrgLevel08Manager OrgLevel09ID OrgLevel09 OrgLevel09Manager  \
# Emplid
# 74928    Marie Sheffield          NaN        NaN               NaN
# 9327          Jon Colson          NaN        NaN               NaN
# 21204                NaN          NaN        NaN               NaN
# 33490                NaN          NaN        NaN               NaN
# 89973                NaN          NaN        NaN               NaN
#
#         OrgLevel10ID  OrgLevel10  OrgLevel10Manager         Manager_Location  \
# Emplid
# 74928            NaN         NaN                NaN                  Dorking
# 9327             NaN         NaN                NaN     Portland Home Office
# 21204            NaN         NaN                NaN                      NaN
# 33490            NaN         NaN                NaN      Roswell Sales - CLA
# 89973            NaN         NaN                NaN  Chattanooga Home Office
#
#                                   Supervisory_Org_L1_Away  \
# Emplid
# 74928                 UK Broker Services (Louise Cauchie)
# 9327    Closed Block LTC Benefits Operations (John Noble)
# 21204                     VB & Colonial Life (Tim Arnold)
# 33490                     VB & Colonial Life (Tim Arnold)
# 89973   Benefit & Contact Center Journey Tech (Mike Sc...
#
#                                   Supervisory_Org_L2_Away  \
# Emplid
# 74928                UK Broker Services (James Vallender)
# 9327    Closed Block LTC Benefits Operations (Stephani...
# 21204                    Unum Group COO (Michael Simonds)
# 33490                    Unum Group COO (Michael Simonds)
# 89973                 Information Technology (Gautam Roy)
#
#                                   Supervisory_Org_L3_Away  \
# Emplid
# 74928              Unum UK Customer Services (Liz Walker)
# 9327    Unum US Group Life & LTC Benefits (Michelle Br...
# 21204                          Unum Group (Rick McKenney)
# 33490                          Unum Group (Rick McKenney)
# 89973       Technology and Transformation (Puneet Bhasin)
#
#                           Supervisory_Org_L4_Away  \
# Emplid
# 74928              Unum International (Mark Till)
# 9327    Unum US Benefits Operations (Lori Whynot)
# 21204              Unum Executive (Rick McKenney)
# 33490              Unum Executive (Rick McKenney)
# 89973                  Unum Group (Rick McKenney)
#
#                  Supervisory_Org_L5_Away     Supervisory_Org_L6_Away  \
# Emplid
# 74928   Unum Group COO (Michael Simonds)  Unum Group (Rick McKenney)
# 9327    Unum Group COO (Michael Simonds)  Unum Group (Rick McKenney)
# 21204                                NaN                         NaN
# 33490                                NaN                         NaN
# 89973     Unum Executive (Rick McKenney)                         NaN
#
#                Supervisory_Org_L7_Away Supervisory_Org_L8_Away  \
# Emplid
# 74928   Unum Executive (Rick McKenney)                     NaN
# 9327    Unum Executive (Rick McKenney)                     NaN
# 21204                              NaN                     NaN
# 33490                              NaN                     NaN
# 89973                              NaN                     NaN
#
#         Supervisory_Org_L9_Away  Supervisory_Org_L10_Away  \
# Emplid
# 74928                       NaN                       NaN
# 9327                        NaN                       NaN
# 21204                       NaN                       NaN
# 33490                       NaN                       NaN
# 89973                       NaN                       NaN
#
#              Worker_Supervisory_Org_L1   Worker_Supervisory_Org_L2  \
# Emplid
# 74928   Unum Executive (Rick McKenney)  Unum Group (Rick McKenney)
# 9327                               NaN                         NaN
# 21204                              NaN                         NaN
# 33490                              NaN                         NaN
# 89973                              NaN                         NaN
#
#                Worker_Supervisory_Org_L3       Worker_Supervisory_Org_L4  \
# Emplid
# 74928   Unum Group COO (Michael Simonds)  Unum International (Mark Till)
# 9327                                 NaN                             NaN
# 21204                                NaN                             NaN
# 33490                                NaN                             NaN
# 89973                                NaN                             NaN
#
#                        Worker_Supervisory_Org_L5  \
# Emplid
# 74928   UK_Finance & Underwriting (Jon Fletcher)
# 9327                                         NaN
# 21204                                        NaN
# 33490                                        NaN
# 89973                                        NaN
#
#                    Worker_Supervisory_Org_L6  \
# Emplid
# 74928   UK Financial Control (Deirdre Flood)
# 9327                                     NaN
# 21204                                    NaN
# 33490                                    NaN
# 89973                                    NaN
#
#                                 Worker_Supervisory_Org_L7  \
# Emplid
# 74928   UK Financial Planning and Analysis (Deirdre Fl...
# 9327                                                  NaN
# 21204                                                 NaN
# 33490                                                 NaN
# 89973                                                 NaN
#
#                                 Worker_Supervisory_Org_L8  \
# Emplid
# 74928   UK Financial Planning and Analysis (Graham Cop...
# 9327                                                  NaN
# 21204                                                 NaN
# 33490                                                 NaN
# 89973                                                 NaN
#
#        Worker_Supervisory_Org_L9  Worker_Supervisory_Org_L10
# Emplid
# 74928                        NaN                         NaN
# 9327                         NaN                         NaN
# 21204                        NaN                         NaN
# 33490                        NaN                         NaN
# 89973                        NaN                         NaN

# %%
recordstart = '2019-01-01'
recordend = '2019-06-30'

# %%
turnover4 = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Trended_Worker_Turnover_Details?IncludeSubOrgs=1&Active=0&Record_Start={0}-08%3A00&Remove_Exclude_From_HC=0&Record_End={1}-08%3A00&SupervisoryOrg%21WID=fad8c8a44c4510541494e34161d00311&format=csv'.format(recordstart,recordend)
with requests.Session() as s:
    download = s.get(turnover4, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    turnover4 = pd.read_csv(io.StringIO(decoded_content))
    turnover4 = turnover4.set_index('Emplid')
# Out:
# C:\Users\DDY17\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11,12,13,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(turnover4.shape)
turnover4.head()
# Out:
# (80109, 143)
#        Year-Quarter  Month Record_Date Record_Type LAN_ID Preferred_Name  \
# Emplid
# 93856       2019-Q1      1  2019-01-01    Activity  BTP17    Layak Singh
# 53214       2019-Q1      1  2019-01-01    Activity  $ITDT   Daniel Taber
# 27120       2019-Q1      1  2019-01-01    Activity  $DPJM  Mike McCleery
# 1103        2019-Q1      1  2019-01-01    Activity  PRDEM   Dave McMahon
# 39570       2019-Q1      1  2019-01-01    Activity  G3U12     Tim Powell
#
#                                   Worker               Work_Email        Hire  \
# Emplid
# 93856   Layak Singh [C] (Contract Ended)  LSingh@ColonialLife.com  2017-08-02
# 53214          Daniel Taber (Terminated)          DTaber@UNUM.COM  2003-03-17
# 27120         Mike McCleery (Terminated)       MMcCleery@UNUM.COM  2001-05-01
# 1103           Dave McMahon (Terminated)        dmcmahon@unum.com  1985-04-08
# 39570            Tim Powell (Terminated)    Tim.POWELL@unum.co.uk  1989-07-24
#
#        OriginalHireAtRecordDate                      Term_Event  \
# Emplid
# 93856                2017-08-02  End Contingent Worker Contract
# 53214                2003-03-17              Terminate Employee
# 27120                1986-07-28              Terminate Employee
# 1103                 1985-04-08              Terminate Employee
# 39570                1989-07-24                             NaN
#
#                      Term_Category   Term_Reason Secondary_Term_Reason  \
# Emplid
# 93856                    Voluntary      Personal                   NaN
# 53214   Job Elimination/Redundancy  No Placement                   NaN
# 27120   Job Elimination/Redundancy  No Placement                   NaN
# 1103    Job Elimination/Redundancy  No Placement                   NaN
# 39570                          NaN           NaN                   NaN
#
#         Is_Term_90-Day  Is_Term_New_Hire Is_Rehire_Eligible         Tenure  \
# Emplid
# 93856                0                 0                NaN  01 - 02 Years
# 53214                0                 0                NaN  15 - 20 Years
# 27120                0                 0                NaN  15 - 20 Years
# 1103                 0                 0                NaN      25+ Years
# 39570                0                 0                NaN      25+ Years
#
#         Years_of_Service     Age_Group  Age  Diverse Gender Gender_Identity  \
# Emplid
# 93856               1.41  24 and under    0        0    NaN             NaN
# 53214              15.79   60 and over   60        0   Male             NaN
# 27120              17.67       55 - 59   59        0   Male             NaN
# 1103               33.73   60 and over   61        0   Male             NaN
# 39570              29.44       45 - 49   48        0   Male            Male
#
#        Sexual_Orientation     Pronoun                          Ethnicity  \
# Emplid
# 93856                 NaN         NaN                                NaN
# 53214                 NaN         NaN   White (United States of America)
# 27120                 NaN         NaN   White (United States of America)
# 1103                  NaN         NaN   White (United States of America)
# 39570        Heterosexual  He/Him/His  White (United Kingdom) (inactive)
#
#         Hispanic_Latino  Minority MinorityStatus  Disability DisabilityStatus  \
# Emplid
# 93856                 0         0   Non-Minority           0              NaN
# 53214                 0         0   Non-Minority           0              NaN
# 27120                 0         0   Non-Minority           0              NaN
# 1103                  0         0   Non-Minority           0              NaN
# 39570                 0         0   Non-Minority           0              NaN
#
#                    Disability_Self_ID  Veteran VeteranStatus MilitaryStatus  \
# Emplid
# 93856                             NaN        0           NaN            NaN
# 53214                             NaN        0           NaN            NaN
# 27120   NO, I DON'T HAVE A DISABILITY        0           NaN            NaN
# 1103                              NaN        0           NaN            NaN
# 39570                             NaN        0           NaN            NaN
#
#        Highest_Degree  On_Leave  Active Management_Level            Job_Level  \
# Emplid
# 93856             NaN         0       0              NaN                  NaN
# 53214       Bachelors         0       0     3 Management          2 Directors
# 27120       Bachelors         0       0         2 Leader  1.3 VP & Equivalent
# 1103            Other         0       0  1 Senior Leader  1.3 VP & Equivalent
# 39570             NaN         0       1         2 Leader  1.3 VP & Equivalent
#
#               Job_Family_Group                   Job_Family   Job_Code  \
# Emplid
# 93856       Contingent Workers       Contingent Worker Jobs      CW001
# 53214   Information Technology  Information Technology Jobs  IT803-USA
# 27120   Information Technology  Information Technology Jobs  IT805-USA
# 1103    Information Technology  Information Technology Jobs  IT219-USA
# 39570                      NaN            Customer Services    L094-UK
#
#                                           Job_Profile Business_Title  \
# Emplid
# 93856                         Contract Service Worker            NaN
# 53214    Technology Capability Manager, US (inactive)            NaN
# 27120   Technology Capability Officer,  US (inactive)            NaN
# 1103                               VP, Technology, US            NaN
# 39570                         Head of Broker Services            NaN
#
#         YearsInJobAtRecordDate Years_In_Job  \
# Emplid
# 93856                     1.41  02-05 Years
# 53214                     3.66  05-10 Years
# 27120                     1.00  02-05 Years
# 1103                      3.66  05-10 Years
# 39570                     0.00  02-05 Years
#
#                               Time_in_Job  Position_ID Grade  Annual_Salary  \
# Emplid
# 93856    1 year(s), 4 month(s), 29 day(s)          NaN   NaN            0.0
# 53214    3 year(s), 7 month(s), 28 day(s)          NaN    14       120405.0
# 27120   0 year(s), 11 month(s), 30 day(s)          NaN    16       197239.0
# 1103     3 year(s), 7 month(s), 28 day(s)          NaN    17       235280.0
# 39570    4 year(s), 2 month(s), 30 day(s)     304213.0    16       152906.9
#
#         Annual_FTE_Salary  Salary_Range_Minimum  Salary_Range_Midpoint  \
# Emplid
# 93856                 0.0                     0                      0
# 53214            120405.0                 91200                 134500
# 27120            197239.0                142400                 210050
# 1103             235280.0                178000                 262550
# 39570            120770.0                 87400                 118000
#
#         Salary_Range_Maximum  Is_Org_Manager  Is_People_Manager  \
# Emplid
# 93856                      0               0                  0
# 53214                 177800               1                  0
# 27120                 277700               0                  0
# 1103                  347100               1                  0
# 39570                 148600               1                  0
#
#         Direct_Reports  FTE  Exempt Full_Part_Time        Worker_Type  \
# Emplid
# 93856                0  1.0       0      Full time  Contingent Worker
# 53214                0  1.0       1      Full time           Employee
# 27120                0  1.0       1      Full time           Employee
# 1103                 0  1.0       1      Full time           Employee
# 39570                0  1.0       0      Full time           Employee
#
#        Employee_Type          Contingent_Type  \
# Emplid
# 93856            NaN  Vendor - Contract Labor
# 53214        Regular                      NaN
# 27120        Regular                      NaN
# 1103         Regular                      NaN
# 39570        Regular                      NaN
#
#                                   Potential  \
# Emplid
# 93856                                   NaN
# 53214                           Well Placed
# 27120   High Impact Leader at Current Level
# 1103    High Impact Leader at Current Level
# 39570                           Well Placed
#
#                                             Company                   Country  \
# Emplid
# 93856                              C3035 Unum Group  United States of America
# 53214                              C3035 Unum Group  United States of America
# 27120                              C3035 Unum Group  United States of America
# 1103                               C3035 Unum Group  United States of America
# 39570   C5094 Unum European Holding Company Limited            United Kingdom
#
#                Campus                 Location Work_Address_State  \
# Emplid
# 93856   International            International                NaN
# 53214     Chattanooga  Chattanooga Home Office                NaN
# 27120     Chattanooga  Chattanooga Home Office                NaN
# 1103      Chattanooga  Chattanooga Home Office                NaN
# 39570         Dorking                  Dorking             Surrey
#
#                  Business_Area             Profile_Area  \
# Emplid
# 93856            US Operations  Unum US Benefits Center
# 53214   Information Technology         Information Tech
# 27120   Information Technology         Information Tech
# 1103    Information Technology         Information Tech
# 39570                  Unum UK           Unum UK Direct
#
#                        Department    Consolidated_Area  \
# Emplid
# 93856                  CLA Claims               Claims
# 53214      Information Technology  Operations Services
# 27120      Information Technology        Office Of CTO
# 1103       Information Technology  Operations Services
# 39570   Unum UK Customer Services      Broker Services
#
#                           Area                    Sub_Area Cost_Center_ID  \
# Emplid
# 93856               Claims Ops           Claims Operations         EC6217
# 53214    Inactive Cost Centers          Inactive Cost Ctrs         EC1645
# 27120   Infrastructure Sr Mgmt  Infrastructure Senior Mgmt         EC0400
# 1103     Inactive Cost Centers          Inactive Cost Ctrs         EC1644
# 39570          Broker_Services                  Brkr Srvcs         EC7028
#
#        Cost_Center                         BP_Type  End_Headcount  Hires  \
# Emplid
# 93856          NaN  End Contingent Worker Contract              0      0
# 53214          NaN                     Termination              0      0
# 27120          NaN                     Termination              0      0
# 1103           NaN                     Termination              0      0
# 39570          NaN               Transfer Employee              0      0
#
#         Promotion  Transfer_Out  Transfer_In  Termination  \
# Emplid
# 93856           0             0            0            1
# 53214           0             0            0            1
# 27120           0             0            0            1
# 1103            0             0            0            1
# 39570           0             1            0            0
#
#         Voluntary_Termination  Involuntary_Termination SupervisoryOrgID  \
# Emplid
# 93856                       1                        0  SupOrg_00295931
# 53214                       0                        1  SupOrg_00303218
# 27120                       0                        1  SupOrg_00302588
# 1103                        0                        1  SupOrg_00302588
# 39570                       0                        0  SupOrg_00293589
#
#                               SupervisoryOrg        OrgManager  OrgLevel  \
# Emplid
# 93856   Colonial Life A&H/Life/Cancer Claims  Michelle Boucher         6
# 53214                      End User Services       Blake Pease         5
# 27120                 Information Technology        Gautam Roy         4
# 1103                  Information Technology        Gautam Roy         4
# 39570              Unum UK Customer Services        Liz Walker         5
#
#             OrgLevel01ID      OrgLevel01 OrgLevel01Manager     OrgLevel02ID  \
# Emplid
# 93856   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 53214   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 27120   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 1103    SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 39570   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
#
#         OrgLevel02 OrgLevel02Manager     OrgLevel03ID  \
# Emplid
# 93856   Unum Group     Rick McKenney  SupOrg_00112942
# 53214   Unum Group     Rick McKenney  SupOrg_00300846
# 27120   Unum Group     Rick McKenney  SupOrg_00300846
# 1103    Unum Group     Rick McKenney  SupOrg_00300846
# 39570   Unum Group     Rick McKenney  SupOrg_00112942
#
#                            OrgLevel03 OrgLevel03Manager     OrgLevel04ID  \
# Emplid
# 93856                  Unum Group COO   Michael Simonds  SupOrg_00309192
# 53214   Technology and Transformation     Puneet Bhasin  SupOrg_00302588
# 27120   Technology and Transformation     Puneet Bhasin  SupOrg_00302588
# 1103    Technology and Transformation     Puneet Bhasin  SupOrg_00302588
# 39570                  Unum Group COO   Michael Simonds  SupOrg_00051934
#
#                                                OrgLevel04 OrgLevel04Manager  \
# Emplid
# 93856   Customer Experience Center/Absence Management ...  Michelle Boucher
# 53214                              Information Technology        Gautam Roy
# 27120                              Information Technology        Gautam Roy
# 1103                               Information Technology        Gautam Roy
# 39570                                  Unum International         Mark Till
#
#            OrgLevel05ID                       OrgLevel05 OrgLevel05Manager  \
# Emplid
# 93856   SupOrg_00000505  Colonial Life Disability Claims  Michelle Boucher
# 53214   SupOrg_00303218                End User Services       Blake Pease
# 27120               NaN                              NaN               NaN
# 1103                NaN                              NaN               NaN
# 39570   SupOrg_00293589        Unum UK Customer Services        Liz Walker
#
#            OrgLevel06ID                            OrgLevel06  \
# Emplid
# 93856   SupOrg_00295931  Colonial Life A&H/Life/Cancer Claims
# 53214               NaN                                   NaN
# 27120               NaN                                   NaN
# 1103                NaN                                   NaN
# 39570               NaN                                   NaN
#
#        OrgLevel06Manager OrgLevel07ID OrgLevel07 OrgLevel07Manager  \
# Emplid
# 93856   Michelle Boucher          NaN        NaN               NaN
# 53214                NaN          NaN        NaN               NaN
# 27120                NaN          NaN        NaN               NaN
# 1103                 NaN          NaN        NaN               NaN
# 39570                NaN          NaN        NaN               NaN
#
#        OrgLevel08ID OrgLevel08 OrgLevel08Manager OrgLevel09ID OrgLevel09  \
# Emplid
# 93856           NaN        NaN               NaN          NaN        NaN
# 53214           NaN        NaN               NaN          NaN        NaN
# 27120           NaN        NaN               NaN          NaN        NaN
# 1103            NaN        NaN               NaN          NaN        NaN
# 39570           NaN        NaN               NaN          NaN        NaN
#
#        OrgLevel09Manager  OrgLevel10ID  OrgLevel10  OrgLevel10Manager  \
# Emplid
# 93856                NaN           NaN         NaN                NaN
# 53214                NaN           NaN         NaN                NaN
# 27120                NaN           NaN         NaN                NaN
# 1103                 NaN           NaN         NaN                NaN
# 39570                NaN           NaN         NaN                NaN
#
#                  Manager_Location  \
# Emplid
# 93856   Colonial Life Home Office
# 53214        Portland Home Office
# 27120     Chattanooga Home Office
# 1103      Chattanooga Home Office
# 39570                         NaN
#
#                                   Supervisory_Org_L1_Away  \
# Emplid
# 93856   Colonial Life Disability Claims (Michelle Bouc...
# 53214                 Information Technology (Gautam Roy)
# 27120       Technology and Transformation (Puneet Bhasin)
# 1103        Technology and Transformation (Puneet Bhasin)
# 39570                      Unum International (Mark Till)
#
#                                   Supervisory_Org_L2_Away  \
# Emplid
# 93856   Customer Experience Center/Absence Management ...
# 53214       Technology and Transformation (Puneet Bhasin)
# 27120                          Unum Group (Rick McKenney)
# 1103                           Unum Group (Rick McKenney)
# 39570                    Unum Group COO (Michael Simonds)
#
#                  Supervisory_Org_L3_Away         Supervisory_Org_L4_Away  \
# Emplid
# 93856   Unum Group COO (Michael Simonds)      Unum Group (Rick McKenney)
# 53214         Unum Group (Rick McKenney)  Unum Executive (Rick McKenney)
# 27120     Unum Executive (Rick McKenney)                             NaN
# 1103      Unum Executive (Rick McKenney)                             NaN
# 39570         Unum Group (Rick McKenney)  Unum Executive (Rick McKenney)
#
#                Supervisory_Org_L5_Away Supervisory_Org_L6_Away  \
# Emplid
# 93856   Unum Executive (Rick McKenney)                     NaN
# 53214                              NaN                     NaN
# 27120                              NaN                     NaN
# 1103                               NaN                     NaN
# 39570                              NaN                     NaN
#
#        Supervisory_Org_L7_Away Supervisory_Org_L8_Away  \
# Emplid
# 93856                      NaN                     NaN
# 53214                      NaN                     NaN
# 27120                      NaN                     NaN
# 1103                       NaN                     NaN
# 39570                      NaN                     NaN
#
#         Supervisory_Org_L9_Away  Supervisory_Org_L10_Away  \
# Emplid
# 93856                       NaN                       NaN
# 53214                       NaN                       NaN
# 27120                       NaN                       NaN
# 1103                        NaN                       NaN
# 39570                       NaN                       NaN
#
#        Worker_Supervisory_Org_L1 Worker_Supervisory_Org_L2  \
# Emplid
# 93856                        NaN                       NaN
# 53214                        NaN                       NaN
# 27120                        NaN                       NaN
# 1103                         NaN                       NaN
# 39570                        NaN                       NaN
#
#        Worker_Supervisory_Org_L3 Worker_Supervisory_Org_L4  \
# Emplid
# 93856                        NaN                       NaN
# 53214                        NaN                       NaN
# 27120                        NaN                       NaN
# 1103                         NaN                       NaN
# 39570                        NaN                       NaN
#
#        Worker_Supervisory_Org_L5 Worker_Supervisory_Org_L6  \
# Emplid
# 93856                        NaN                       NaN
# 53214                        NaN                       NaN
# 27120                        NaN                       NaN
# 1103                         NaN                       NaN
# 39570                        NaN                       NaN
#
#        Worker_Supervisory_Org_L7 Worker_Supervisory_Org_L8  \
# Emplid
# 93856                        NaN                       NaN
# 53214                        NaN                       NaN
# 27120                        NaN                       NaN
# 1103                         NaN                       NaN
# 39570                        NaN                       NaN
#
#        Worker_Supervisory_Org_L9  Worker_Supervisory_Org_L10
# Emplid
# 93856                        NaN                         NaN
# 53214                        NaN                         NaN
# 27120                        NaN                         NaN
# 1103                         NaN                         NaN
# 39570                        NaN                         NaN

# %%
recordstart = '2019-07-01'
recordend = '2019-12-31'

# %%
turnover5 = 'https://services1.myworkday.com/ccx/service/customreport2/unum/DKJ05/RaaS_Trended_Worker_Turnover_Details?IncludeSubOrgs=1&Active=0&Record_Start={0}-08%3A00&Remove_Exclude_From_HC=0&Record_End={1}-08%3A00&SupervisoryOrg%21WID=fad8c8a44c4510541494e34161d00311&format=csv'.format(recordstart,recordend)
with requests.Session() as s:
    download = s.get(turnover5, auth=(username, password))
    decoded_content = download.content.decode('utf-8')
    turnover5 = pd.read_csv(io.StringIO(decoded_content))
    turnover5 = turnover5.set_index('Emplid')
# Out:
# C:\Users\DDY17\Anaconda3\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11,12,13,80) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(turnover5.shape)
turnover5.head()
# Out:
# (83690, 143)
#        Year-Quarter  Month Record_Date Record_Type LAN_ID   Preferred_Name  \
# Emplid
# 100495      2019-Q3      7  2019-07-01    Activity  AYA19  Mahesh Manickam
# 91351       2019-Q3      7  2019-07-01    Activity  BVK16     Eddie Gorman
# 93303       2019-Q3      7  2019-07-01    Activity  BFD17    Martin Reilly
# 100515      2019-Q3      7  2019-07-01    Activity  AYL19      Nedra Price
# 75931       2019-Q3      7  2019-07-01    Activity  BQQ13     Robert Hogan
#
#                                       Worker           Work_Email        Hire  \
# Emplid
# 100495  Mahesh Manickam [C] (Contract Ended)  MManickam2@UNUM.COM  2019-03-19
# 91351                           Eddie Gorman     EGorman@unum.com  2016-10-18
# 93303                          Martin Reilly     MReilly@UNUM.COM  2017-06-12
# 100515      Nedra Price [C] (Contract Ended)      NPrice@UNUM.COM  2019-02-11
# 75931                           Robert Hogan     RHogan2@UNUM.COM  2014-01-03
#
#        OriginalHireAtRecordDate                      Term_Event Term_Category  \
# Emplid
# 100495               2019-03-19  End Contingent Worker Contract     Voluntary
# 91351                2016-10-18                             NaN           NaN
# 93303                2017-06-12                             NaN           NaN
# 100515               2019-02-11  End Contingent Worker Contract     Voluntary
# 75931                2014-01-03                             NaN           NaN
#
#                 Term_Reason Secondary_Term_Reason  Is_Term_90-Day  \
# Emplid
# 100495              Unknown                   NaN               0
# 91351                   NaN                   NaN               0
# 93303                   NaN                   NaN               0
# 100515  Convert to Employee                   NaN               0
# 75931                   NaN                   NaN               0
#
#         Is_Term_New_Hire Is_Rehire_Eligible         Tenure  Years_of_Service  \
# Emplid
# 100495                 1                NaN  00 - 01 Years              0.28
# 91351                  0                NaN  02 - 05 Years              2.70
# 93303                  0                NaN  02 - 05 Years              2.05
# 100515                 1                NaN  00 - 01 Years              0.39
# 75931                  0                NaN  05 - 10 Years              5.49
#
#            Age_Group  Age  Diverse  Gender Gender_Identity Sexual_Orientation  \
# Emplid
# 100495  24 and under    0        0     NaN             NaN                NaN
# 91351        30 - 34   34        0    Male             NaN                NaN
# 93303        30 - 34   30        0    Male             NaN                NaN
# 100515       35 - 39   36        1  Female             NaN                NaN
# 75931        45 - 49   48        0    Male             NaN                NaN
#
#        Pronoun                                 Ethnicity  Hispanic_Latino  \
# Emplid
# 100495     NaN                                       NaN                0
# 91351      NaN                           White (Ireland)                0
# 93303      NaN                           White (Ireland)                0
# 100515     NaN  Not Indicated (United States of America)                0
# 75931      NaN                           White (Ireland)                0
#
#         Minority MinorityStatus  Disability DisabilityStatus  \
# Emplid
# 100495         0   Non-Minority           0              NaN
# 91351          0   Non-Minority           0              NaN
# 93303          0   Non-Minority           0              NaN
# 100515         0   Non-Minority           0              NaN
# 75931          0   Non-Minority           0              NaN
#
#        Disability_Self_ID  Veteran VeteranStatus MilitaryStatus  \
# Emplid
# 100495                NaN        0           NaN            NaN
# 91351                 NaN        0           NaN            NaN
# 93303                 NaN        0           NaN            NaN
# 100515                NaN        0           NaN            NaN
# 75931                 NaN        0           NaN            NaN
#
#                    Highest_Degree  On_Leave  Active          Management_Level  \
# Emplid
# 100495                        NaN         0       0                       NaN
# 91351                         NaN         0       1  5 Individual Contributor
# 93303                         NaN         0       1  5 Individual Contributor
# 100515                        NaN         0       0                       NaN
# 75931   Diploma/Level 4-5 NVQ/SVQ         0       1  5 Individual Contributor
#
#                                         Job_Level        Job_Family_Group  \
# Emplid
# 100495                                        NaN      Contingent Workers
# 91351   5.2 Professional - Individual Contributor  Information Technology
# 93303   5.2 Professional - Individual Contributor  Information Technology
# 100515                                        NaN      Contingent Workers
# 75931   5.2 Professional - Individual Contributor  Information Technology
#
#                          Job_Family   Job_Code               Job_Profile  \
# Emplid
# 100495       Contingent Worker Jobs      CW001   Contract Service Worker
# 91351   Information Technology Jobs  IT844-IRE        UX Designer I, IRE
# 93303   Information Technology Jobs  IT844-IRE        UX Designer I, IRE
# 100515       Contingent Worker Jobs      CW003  Temp Worker (short-term)
# 75931   Information Technology Jobs  IT794-IRE   Business Analyst I, IRE
#
#                       Business_Title  YearsInJobAtRecordDate Years_In_Job  \
# Emplid
# 100495                           NaN                    0.28  01-02 Years
# 91351            UX Designer II, IRE                    0.00  01-02 Years
# 93303            UX Designer II, IRE                    0.00  01-02 Years
# 100515                           NaN                    0.38  02-05 Years
# 75931   Senior Business Analyst, IRE                    0.00  01-02 Years
#
#                              Time_in_Job  Position_ID Grade  Annual_Salary  \
# Emplid
# 100495  0 year(s), 3 month(s), 11 day(s)          NaN   NaN           0.00
# 91351   0 year(s), 8 month(s), 29 day(s)     310991.0    11       47217.28
# 93303   0 year(s), 8 month(s), 29 day(s)     310992.0    11       53658.26
# 100515  0 year(s), 4 month(s), 19 day(s)          NaN   NaN           0.00
# 75931   1 year(s), 9 month(s), 26 day(s)     310582.0    11       62256.77
#
#         Annual_FTE_Salary  Salary_Range_Minimum  Salary_Range_Midpoint  \
# Emplid
# 100495                0.0                     0                    0.0
# 91351             49000.0                 38600                55900.0
# 93303             52000.0                 38600                55900.0
# 100515                0.0                     0                    0.0
# 75931             60000.0                 46300                67100.0
#
#         Salary_Range_Maximum  Is_Org_Manager  Is_People_Manager  \
# Emplid
# 100495                     0               0                  0
# 91351                  73200               0                  0
# 93303                  73200               0                  0
# 100515                     0               0                  0
# 75931                  87900               0                  0
#
#         Direct_Reports  FTE  Exempt Full_Part_Time        Worker_Type  \
# Emplid
# 100495               0  1.0       0      Full time  Contingent Worker
# 91351                0  1.0       1      Full time           Employee
# 93303                0  1.0       1      Full time           Employee
# 100515               0  1.0       0      Full time  Contingent Worker
# 75931                0  1.0       0      Full time           Employee
#
#        Employee_Type          Contingent_Type                   Potential  \
# Emplid
# 100495           NaN  Vendor - Contract Labor                         NaN
# 91351        Regular                      NaN                         NaN
# 93303        Regular                      NaN  Longer Term High Potential
# 100515           NaN               Temp Staff                         NaN
# 75931        Regular                      NaN    Near Term High Potential
#
#                            Company                   Country       Campus  \
# Emplid
# 100495            C3035 Unum Group  United States of America  Chattanooga
# 91351   C5020 Unum Ireland Limited                   Ireland      Ireland
# 93303   C5020 Unum Ireland Limited                   Ireland      Ireland
# 100515            C3035 Unum Group  United States of America  Baton Rouge
# 75931   C5020 Unum Ireland Limited                   Ireland      Ireland
#
#                        Location Work_Address_State           Business_Area  \
# Emplid
# 100495  Chattanooga Home Office                NaN  Information Technology
# 91351                    Carlow             Carlow  Information Technology
# 93303                    Carlow             Carlow  Information Technology
# 100515  Baton Rouge Home Office                NaN           US Operations
# 75931                    Carlow             Carlow  Information Technology
#
#                    Profile_Area              Department  \
# Emplid
# 100495         Information Tech           Office Of CTO
# 91351          Information Tech                   UX IT
# 93303          Information Tech                   UX IT
# 100515  Unum Specialty Business  Unum Dental and Vision
# 75931          Information Tech       IT Transformation
#
#                           Consolidated_Area                          Area  \
# Emplid
# 100495                            Risk Mgmt               Risk Management
# 91351                        UX - Info Tech                       UX Area
# 93303                        UX - Info Tech                       UX Area
# 100515         Dental and Vision Operations  Dental_and_Vision_Operations
# 75931   Digital Ventures and Transformation        Solutions Journey Tech
#
#                         Sub_Area Cost_Center_ID         Cost_Center  \
# Emplid
# 100495         Risk Mgmt Staff_2         EC0490                 NaN
# 91351                        UX.         EC1586              UX IRE
# 93303                        UX.         EC1586              UX IRE
# 100515  Dental and Vision Claims         EC3148                 NaN
# 75931              HR Connect IT         EC1532  IRE Data Analytics
#
#                                BP_Type  End_Headcount  Hires  Promotion  \
# Emplid
# 100495  End Contingent Worker Contract              0      0          0
# 91351        Promote Employee Outbound              0      0          1
# 93303        Promote Employee Outbound              0      0          1
# 100515  End Contingent Worker Contract              0      0          0
# 75931        Promote Employee Outbound              0      0          1
#
#         Transfer_Out  Transfer_In  Termination  Voluntary_Termination  \
# Emplid
# 100495             0            0            1                      1
# 91351              0            0            0                      0
# 93303              0            0            0                      0
# 100515             0            0            1                      1
# 75931              0            0            0                      0
#
#         Involuntary_Termination SupervisoryOrgID  \
# Emplid
# 100495                        0  SupOrg_00306490
# 91351                         0  SupOrg_00218705
# 93303                         0  SupOrg_00218705
# 100515                        0    SupOrg_101887
# 75931                         0  SupOrg_00213165
#
#                                  SupervisoryOrg     OrgManager  OrgLevel  \
# Emplid
# 100495    Enterprise Security & Risk Management  Marc Bouchard         7
# 91351              Information Technology - IRE    Ken O'Brien         5
# 93303              Information Technology - IRE    Ken O'Brien         5
# 100515           Operation Directors, Starmount   Renee Jaszcz         7
# 75931   Data Analytics & Engineering Excellence  Declan McGill         5
#
#             OrgLevel01ID      OrgLevel01 OrgLevel01Manager     OrgLevel02ID  \
# Emplid
# 100495  SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 91351   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 93303   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 100515  SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
# 75931   SupOrg_Executive  Unum Executive     Rick McKenney  SupOrg_00202594
#
#         OrgLevel02 OrgLevel02Manager     OrgLevel03ID  \
# Emplid
# 100495  Unum Group     Rick McKenney  SupOrg_00300846
# 91351   Unum Group     Rick McKenney  SupOrg_00300846
# 93303   Unum Group     Rick McKenney  SupOrg_00300846
# 100515  Unum Group     Rick McKenney  SupOrg_00112942
# 75931   Unum Group     Rick McKenney  SupOrg_00300846
#
#                            OrgLevel03 OrgLevel03Manager     OrgLevel04ID  \
# Emplid
# 100495  Technology and Transformation     Puneet Bhasin  SupOrg_00302588
# 91351   Technology and Transformation     Puneet Bhasin  SupOrg_00303910
# 93303   Technology and Transformation     Puneet Bhasin  SupOrg_00303910
# 100515                 Unum Group COO   Michael Simonds  SupOrg_00306911
# 75931   Technology and Transformation     Puneet Bhasin  SupOrg_00303910
#
#                     OrgLevel04 OrgLevel04Manager     OrgLevel05ID  \
# Emplid
# 100495  Information Technology        Gautam Roy  SupOrg_00319655
# 91351   Information Technology   Padraig O'Neill  SupOrg_00218705
# 93303   Information Technology   Padraig O'Neill  SupOrg_00218705
# 100515    Unum Specialty Lines     Andrea Gordon  SupOrg_00298756
# 75931   Information Technology   Padraig O'Neill  SupOrg_00213165
#
#                                      OrgLevel05 OrgLevel05Manager  \
# Emplid
# 100495                     Information Security   Matthew Parciak
# 91351              Information Technology - IRE       Ken O'Brien
# 93303              Information Technology - IRE       Ken O'Brien
# 100515           Operation Directors, Starmount       Paul McLean
# 75931   Data Analytics & Engineering Excellence     Declan McGill
#
#            OrgLevel06ID                                         OrgLevel06  \
# Emplid
# 100495  SupOrg_00219597  Enterprise Information Security - Identity & A...
# 91351               NaN                                                NaN
# 93303               NaN                                                NaN
# 100515  SupOrg_00305228                     Operation Directors, Starmount
# 75931               NaN                                                NaN
#
#        OrgLevel06Manager     OrgLevel07ID  \
# Emplid
# 100495     Marc Bouchard  SupOrg_00306490
# 91351                NaN              NaN
# 93303                NaN              NaN
# 100515  Catherine Lackey    SupOrg_101887
# 75931                NaN              NaN
#
#                                    OrgLevel07 OrgLevel07Manager OrgLevel08ID  \
# Emplid
# 100495  Enterprise Security & Risk Management     Marc Bouchard          NaN
# 91351                                     NaN               NaN          NaN
# 93303                                     NaN               NaN          NaN
# 100515         Operation Directors, Starmount      Renee Jaszcz          NaN
# 75931                                     NaN               NaN          NaN
#
#        OrgLevel08 OrgLevel08Manager OrgLevel09ID OrgLevel09 OrgLevel09Manager  \
# Emplid
# 100495        NaN               NaN          NaN        NaN               NaN
# 91351         NaN               NaN          NaN        NaN               NaN
# 93303         NaN               NaN          NaN        NaN               NaN
# 100515        NaN               NaN          NaN        NaN               NaN
# 75931         NaN               NaN          NaN        NaN               NaN
#
#         OrgLevel10ID  OrgLevel10  OrgLevel10Manager         Manager_Location  \
# Emplid
# 100495           NaN         NaN                NaN                      NaN
# 91351            NaN         NaN                NaN                   Carlow
# 93303            NaN         NaN                NaN                   Carlow
# 100515           NaN         NaN                NaN  Baton Rouge Home Office
# 75931            NaN         NaN                NaN                   Carlow
#
#                                   Supervisory_Org_L1_Away  \
# Emplid
# 100495  Enterprise Information Security - Identity & A...
# 91351            Information Technology (Padraig O'Neill)
# 93303            Information Technology (Padraig O'Neill)
# 100515  Operation Directors, Starmount (Catherine Lackey)
# 75931            Information Technology (Padraig O'Neill)
#
#                               Supervisory_Org_L2_Away  \
# Emplid
# 100495         Information Security (Matthew Parciak)
# 91351   Technology and Transformation (Puneet Bhasin)
# 93303   Technology and Transformation (Puneet Bhasin)
# 100515   Operation Directors, Starmount (Paul McLean)
# 75931   Technology and Transformation (Puneet Bhasin)
#
#                      Supervisory_Org_L3_Away  \
# Emplid
# 100495   Information Technology (Gautam Roy)
# 91351             Unum Group (Rick McKenney)
# 93303             Unum Group (Rick McKenney)
# 100515  Unum Specialty Lines (Andrea Gordon)
# 75931             Unum Group (Rick McKenney)
#
#                               Supervisory_Org_L4_Away  \
# Emplid
# 100495  Technology and Transformation (Puneet Bhasin)
# 91351                  Unum Executive (Rick McKenney)
# 93303                  Unum Executive (Rick McKenney)
# 100515               Unum Group COO (Michael Simonds)
# 75931                  Unum Executive (Rick McKenney)
#
#            Supervisory_Org_L5_Away         Supervisory_Org_L6_Away  \
# Emplid
# 100495  Unum Group (Rick McKenney)  Unum Executive (Rick McKenney)
# 91351                          NaN                             NaN
# 93303                          NaN                             NaN
# 100515  Unum Group (Rick McKenney)  Unum Executive (Rick McKenney)
# 75931                          NaN                             NaN
#
#        Supervisory_Org_L7_Away Supervisory_Org_L8_Away  \
# Emplid
# 100495                     NaN                     NaN
# 91351                      NaN                     NaN
# 93303                      NaN                     NaN
# 100515                     NaN                     NaN
# 75931                      NaN                     NaN
#
#         Supervisory_Org_L9_Away  Supervisory_Org_L10_Away  \
# Emplid
# 100495                      NaN                       NaN
# 91351                       NaN                       NaN
# 93303                       NaN                       NaN
# 100515                      NaN                       NaN
# 75931                       NaN                       NaN
#
#              Worker_Supervisory_Org_L1   Worker_Supervisory_Org_L2  \
# Emplid
# 100495                             NaN                         NaN
# 91351   Unum Executive (Rick McKenney)  Unum Group (Rick McKenney)
# 93303   Unum Executive (Rick McKenney)  Unum Group (Rick McKenney)
# 100515                             NaN                         NaN
# 75931   Unum Executive (Rick McKenney)  Unum Group (Rick McKenney)
#
#                             Worker_Supervisory_Org_L3  \
# Emplid
# 100495                                            NaN
# 91351   Technology and Transformation (Puneet Bhasin)
# 93303   Technology and Transformation (Puneet Bhasin)
# 100515                                            NaN
# 75931   Technology and Transformation (Puneet Bhasin)
#
#                        Worker_Supervisory_Org_L4  \
# Emplid
# 100495                                       NaN
# 91351   Information Technology (Padraig O'Neill)
# 93303   Information Technology (Padraig O'Neill)
# 100515                                       NaN
# 75931   Information Technology (Padraig O'Neill)
#
#                                 Worker_Supervisory_Org_L5  \
# Emplid
# 100495                                                NaN
# 91351          Information Technology - IRE (Ken O'Brien)
# 93303          Information Technology - IRE (Ken O'Brien)
# 100515                                                NaN
# 75931   Data Analytics & Engineering Excellence (Decla...
#
#        Worker_Supervisory_Org_L6 Worker_Supervisory_Org_L7  \
# Emplid
# 100495                       NaN                       NaN
# 91351                        NaN                       NaN
# 93303                        NaN                       NaN
# 100515                       NaN                       NaN
# 75931                        NaN                       NaN
#
#        Worker_Supervisory_Org_L8 Worker_Supervisory_Org_L9  \
# Emplid
# 100495                       NaN                       NaN
# 91351                        NaN                       NaN
# 93303                        NaN                       NaN
# 100515                       NaN                       NaN
# 75931                        NaN                       NaN
#
#         Worker_Supervisory_Org_L10
# Emplid
# 100495                         NaN
# 91351                          NaN
# 93303                          NaN
# 100515                         NaN
# 75931                          NaN

# %%
turnovercombined = pd.concat([turnover, turnover2,turnover3, turnover4, turnover5], axis=0)

# %%
turnovercombined.to_csv(r'O:\people_analytics\scorecards_kpis\ldp\data_build\all_turnover_combined_ldp.csv')

# %%
turnovercombined.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ed65a21b08f8> in <module>
# ----> 1 turnovercombined.head()
#
# NameError: name 'turnovercombined' is not defined
